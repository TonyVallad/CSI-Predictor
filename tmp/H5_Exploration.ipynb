# %% [markdown]
# # h5 Exploration

# %% [markdown]
# ## Global variables

# %%
import os
import h5py
import pandas as pd
import numpy as np
from typing import Dict, List, Optional, Tuple, Union

# Update paths to use relative paths from the notebook location
data_dir = "./data/"
h5_filename = "FO_BitMapData_2017-110^01-0196-V1MR_S7.h5"
h5_filepath = os.path.join(data_dir, h5_filename)

# %% [markdown]
# ## Function to store data from h5 into dataframe

# %%
def explore_h5_structure(h5_filepath: str) -> None:
    """
    Explore and print the structure of an h5 file.
    
    Parameters:
    h5_filepath (str): Path to the h5 file
    """
    try:
        with h5py.File(h5_filepath, 'r') as h5f:
            print(f"=== H5 File Structure: {os.path.basename(h5_filepath)} ===")
            
            def print_structure(name, obj, indent=0):
                spaces = "  " * indent
                if isinstance(obj, h5py.Group):
                    print(f"{spaces}📁 Group: {name}")
                    # Print group attributes
                    if obj.attrs:
                        for attr_name, attr_value in obj.attrs.items():
                            print(f"{spaces}  📝 Attribute: {attr_name} = {attr_value}")
                elif isinstance(obj, h5py.Dataset):
                    print(f"{spaces}📊 Dataset: {name}")
                    print(f"{spaces}  📏 Shape: {obj.shape}")
                    print(f"{spaces}  🔢 Type: {obj.dtype}")
                    # Print dataset attributes
                    if obj.attrs:
                        for attr_name, attr_value in obj.attrs.items():
                            print(f"{spaces}  📝 Attribute: {attr_name} = {attr_value}")
                    
                    # For small datasets, show the first few values
                    if obj.size < 20:
                        print(f"{spaces}  📋 Values: {obj[()]}")
                    elif obj.size < 200:
                        print(f"{spaces}  📋 Sample: {obj[:5] if obj.ndim == 1 else obj[0] if obj.ndim > 1 else obj[()]}")
            
            h5f.visititems(lambda name, obj: print_structure(name, obj, name.count('/')))
            
    except Exception as e:
        print(f"Error reading h5 file: {e}")


def load_h5_to_dataframes(h5_filepath: str) -> Dict[str, pd.DataFrame]:
    """
    Load data from h5 file into multiple dataframes.
    
    Parameters:
    h5_filepath (str): Path to the h5 file
    
    Returns:
    Dict[str, pd.DataFrame]: Dictionary containing different dataframes:
        - 'metadata': General metadata about the dataset
        - 'bbox_data': Bounding box data for all ROIs across all frames
        - 'roi_summary': Summary statistics for each ROI
        - 'frame_summary': Summary data for each frame
    """
    dataframes = {}
    
    try:
        with h5py.File(h5_filepath, 'r') as h5f:
            print(f"Loading data from: {os.path.basename(h5_filepath)}")
            
            # Get the experiment group (should be the first/only group)
            exp_groups = list(h5f.keys())
            if not exp_groups:
                print("No experiment groups found in the h5 file")
                return dataframes
            
            exp_group_name = exp_groups[0]
            exp_group = h5f[exp_group_name]
            print(f"Working with experiment group: {exp_group_name}")
            
            # Extract metadata
            metadata = {}
            if 'Patient' in exp_group:
                metadata['patient'] = exp_group['Patient'][()].decode() if isinstance(exp_group['Patient'][()], bytes) else exp_group['Patient'][()]
            if 'Serie' in exp_group:
                metadata['serie'] = exp_group['Serie'][()].decode() if isinstance(exp_group['Serie'][()], bytes) else exp_group['Serie'][()]
            if 'roi_list' in exp_group:
                roi_list = exp_group['roi_list'][()]
                if isinstance(roi_list[0], bytes):
                    roi_list = [roi.decode() for roi in roi_list]
                metadata['roi_list'] = roi_list
            if 'Clusters_indices' in exp_group:
                metadata['clusters_indices'] = exp_group['Clusters_indices'][()]
            
            metadata['experiment_group'] = exp_group_name
            metadata['file_path'] = h5_filepath
            
            # Create metadata dataframe
            metadata_df = pd.DataFrame([metadata])
            dataframes['metadata'] = metadata_df
            
            # Extract bbox and ROI data
            bbox_data = []
            frame_data = []
            
            # Get all frame keys
            frame_keys = [key for key in exp_group.keys() if key.startswith('frame_')]
            frame_keys.sort()
            
            print(f"Found {len(frame_keys)} frames")
            
            for frame_key in frame_keys:
                frame_group = exp_group[frame_key]
                frame_number = frame_key.replace('frame_', '')
                
                # Frame-level data
                frame_info = {
                    'frame_id': frame_key,
                    'frame_number': int(frame_number),
                    'has_rgb_image': 'image_rgb' in frame_group,
                    'has_grayscale_image': 'image' in frame_group,
                }
                
                if 'image_rgb' in frame_group:
                    frame_info['rgb_image_shape'] = frame_group['image_rgb'].shape
                if 'image' in frame_group:
                    frame_info['grayscale_image_shape'] = frame_group['image'].shape
                
                # Count ROIs in this frame
                roi_count = 0
                for roi in metadata.get('roi_list', []):
                    if f'{roi}_bbox' in frame_group:
                        roi_count += 1
                
                frame_info['roi_count'] = roi_count
                frame_data.append(frame_info)
                
                # Extract ROI bbox data for this frame
                for roi in metadata.get('roi_list', []):
                    bbox_key = f'{roi}_bbox'
                    mask_key = f'{roi}_mask'
                    contour_key = f'{roi}_contour'
                    id_key = f'{roi}_id'
                    
                    if bbox_key in frame_group:
                        bbox = frame_group[bbox_key][()]
                        
                        roi_data = {
                            'frame_id': frame_key,
                            'frame_number': int(frame_number),
                            'roi_name': roi,
                            'bbox_x': bbox[0],
                            'bbox_y': bbox[1],
                            'bbox_width': bbox[2],
                            'bbox_height': bbox[3],
                            'bbox_area': bbox[2] * bbox[3],
                            'has_mask': mask_key in frame_group,
                            'has_contour': contour_key in frame_group,
                            'has_id': id_key in frame_group,
                        }
                        
                        # Add mask information if available
                        if mask_key in frame_group:
                            mask = frame_group[mask_key][()]
                            roi_data['mask_shape'] = mask.shape
                            roi_data['mask_nonzero_pixels'] = np.count_nonzero(mask)
                            roi_data['mask_total_pixels'] = mask.size
                            roi_data['mask_fill_ratio'] = roi_data['mask_nonzero_pixels'] / roi_data['mask_total_pixels']
                        
                        # Add contour information if available
                        if contour_key in frame_group:
                            contour = frame_group[contour_key][()]
                            roi_data['contour_shape'] = contour.shape
                            roi_data['contour_points'] = contour.shape[0] if contour.ndim >= 1 else 0
                        
                        # Add ID information if available
                        if id_key in frame_group:
                            roi_data['roi_id'] = frame_group[id_key][()]
                        
                        bbox_data.append(roi_data)
            
            # Create dataframes
            bbox_df = pd.DataFrame(bbox_data)
            frame_df = pd.DataFrame(frame_data)
            
            dataframes['bbox_data'] = bbox_df
            dataframes['frame_summary'] = frame_df
            
            # Create ROI summary
            if not bbox_df.empty:
                roi_summary = bbox_df.groupby('roi_name').agg({
                    'frame_number': ['count', 'min', 'max'],
                    'bbox_area': ['mean', 'std', 'min', 'max'],
                    'bbox_width': ['mean', 'std'],
                    'bbox_height': ['mean', 'std'],
                    'mask_nonzero_pixels': ['mean', 'std'],
                    'mask_fill_ratio': ['mean', 'std'],
                    'contour_points': ['mean', 'std']
                }).round(2)
                
                # Flatten column names
                roi_summary.columns = ['_'.join(col).strip() for col in roi_summary.columns.values]
                roi_summary = roi_summary.reset_index()
                
                dataframes['roi_summary'] = roi_summary
            
            print(f"Successfully loaded data:")
            print(f"  - Metadata: {len(metadata_df)} rows")
            print(f"  - Bbox data: {len(bbox_df)} rows")
            print(f"  - Frame summary: {len(frame_df)} rows")
            print(f"  - ROI summary: {len(roi_summary)} rows" if 'roi_summary' in dataframes else "  - ROI summary: 0 rows")
            
    except Exception as e:
        print(f"Error loading h5 file: {e}")
        import traceback
        traceback.print_exc()
    
    return dataframes


def get_roi_data_for_frame(h5_filepath: str, frame_number: int, roi_name: str) -> Dict:
    """
    Get detailed data for a specific ROI in a specific frame.
    
    Parameters:
    h5_filepath (str): Path to the h5 file
    frame_number (int): Frame number to extract data from
    roi_name (str): Name of the ROI
    
    Returns:
    Dict: Dictionary containing all available data for the ROI
    """
    try:
        with h5py.File(h5_filepath, 'r') as h5f:
            exp_group_name = list(h5f.keys())[0]
            exp_group = h5f[exp_group_name]
            
            frame_key = f'frame_{frame_number:04d}'
            if frame_key not in exp_group:
                print(f"Frame {frame_key} not found")
                return {}
            
            frame_group = exp_group[frame_key]
            
            roi_data = {
                'frame_number': frame_number,
                'roi_name': roi_name
            }
            
            # Get bbox
            bbox_key = f'{roi_name}_bbox'
            if bbox_key in frame_group:
                bbox = frame_group[bbox_key][()]
                roi_data['bbox'] = bbox
                roi_data['bbox_x'] = bbox[0]
                roi_data['bbox_y'] = bbox[1]
                roi_data['bbox_width'] = bbox[2]
                roi_data['bbox_height'] = bbox[3]
            
            # Get mask
            mask_key = f'{roi_name}_mask'
            if mask_key in frame_group:
                roi_data['mask'] = frame_group[mask_key][()]
            
            # Get contour
            contour_key = f'{roi_name}_contour'
            if contour_key in frame_group:
                roi_data['contour'] = frame_group[contour_key][()]
            
            # Get ID
            id_key = f'{roi_name}_id'
            if id_key in frame_group:
                roi_data['roi_id'] = frame_group[id_key][()]
            
            return roi_data
            
    except Exception as e:
        print(f"Error getting ROI data: {e}")
        return {}

# %% [markdown]
# ## Execution

# %%
# Check if the h5 file exists
if os.path.exists(h5_filepath):
    print(f"✅ H5 file found: {h5_filepath}")
    
    # 1. First, explore the structure of the h5 file
    print("\n" + "="*50)
    print("1. EXPLORING H5 FILE STRUCTURE")
    print("="*50)
    explore_h5_structure(h5_filepath)
    
    # 2. Load data into dataframes
    print("\n" + "="*50)
    print("2. LOADING DATA INTO DATAFRAMES")
    print("="*50)
    dataframes = load_h5_to_dataframes(h5_filepath)
    
    # 3. Display the dataframes
    print("\n" + "="*50)
    print("3. DISPLAYING DATAFRAMES")
    print("="*50)
    
    for df_name, df in dataframes.items():
        print(f"\n📊 {df_name.upper()} DataFrame:")
        print(f"Shape: {df.shape}")
        print(f"Columns: {list(df.columns)}")
        print("Sample data:")
        print(df.head())
        print("-" * 60)
    
    # 4. Example: Get detailed data for a specific ROI and frame
    print("\n" + "="*50)
    print("4. EXAMPLE: DETAILED ROI DATA")
    print("="*50)
    
    # Get available ROI names from metadata
    if 'metadata' in dataframes and not dataframes['metadata'].empty:
        roi_list = dataframes['metadata'].iloc[0]['roi_list']
        if roi_list and len(roi_list) > 0:
            # Get first ROI and first frame
            example_roi = roi_list[0]
            if 'bbox_data' in dataframes and not dataframes['bbox_data'].empty:
                example_frame = dataframes['bbox_data']['frame_number'].iloc[0]
                
                print(f"Getting detailed data for ROI '{example_roi}' in frame {example_frame}")
                roi_data = get_roi_data_for_frame(h5_filepath, example_frame, example_roi)
                
                print(f"ROI Data keys: {list(roi_data.keys())}")
                for key, value in roi_data.items():
                    if key in ['mask', 'contour']:
                        print(f"  {key}: shape {value.shape if hasattr(value, 'shape') else 'N/A'}")
                    else:
                        print(f"  {key}: {value}")
    
    # 5. Save dataframes to CSV files for further analysis
    print("\n" + "="*50)
    print("5. SAVING DATAFRAMES TO CSV")
    print("="*50)
    
    output_dir = "./h5_analysis_output"
    os.makedirs(output_dir, exist_ok=True)
    
    for df_name, df in dataframes.items():
        if not df.empty:
            # Handle complex data types that can't be saved to CSV
            df_copy = df.copy()
            
            # Convert complex columns to string representation
            for col in df_copy.columns:
                if df_copy[col].dtype == 'object':
                    # Check if it contains arrays or complex objects
                    sample_val = df_copy[col].dropna().iloc[0] if not df_copy[col].dropna().empty else None
                    if sample_val is not None and (isinstance(sample_val, (list, tuple, np.ndarray)) or 
                                                   (hasattr(sample_val, 'shape') and len(sample_val.shape) > 0)):
                        df_copy[col] = df_copy[col].astype(str)
            
            output_path = os.path.join(output_dir, f"{df_name}.csv")
            df_copy.to_csv(output_path, index=False)
            print(f"✅ Saved {df_name} to {output_path}")
    
    print(f"\n🎉 Analysis complete! Check the '{output_dir}' directory for CSV files.")
    
else:
    print(f"❌ H5 file not found: {h5_filepath}")
    print("Please check the file path and ensure the file exists.")
# Out:
# ✅ H5 file found: ./data/FO_BitMapData_2017-110^01-0196-V1MR_S7.h5
#
# ==================================================
# 1. EXPLORING H5 FILE STRUCTURE
# ==================================================
# === H5 File Structure: FO_BitMapData_2017-110^01-0196-V1MR_S7.h5 ===
# 📁 Group: 02072025
#   📊 Dataset: 02072025/Clusters_indices
#     📏 Shape: (20,)
#     🔢 Type: int64
#     📋 Sample: [  1 217 228 240 246]
#   📊 Dataset: 02072025/Patient
#     📏 Shape: ()
#     🔢 Type: object
#     📋 Values: b'2017-110^01-0196-V1MR'
#   📊 Dataset: 02072025/Serie
#     📏 Shape: ()
#     🔢 Type: object
#     📋 Values: b'7'
#   📁 Group: 02072025/frame_0001
#     📊 Dataset: 02072025/frame_0001/arytenoid-cartilage_bbox
#       📏 Shape: (4,)
#       🔢 Type: int64
#       📋 Values: [275 361  21  47]
#     📊 Dataset: 02072025/frame_0001/arytenoid-cartilage_contour
#       📏 Shape: (21, 2)
#       🔢 Type: int64
#       📋 Sample: [296 361]
#     📊 Dataset: 02072025/frame_0001/arytenoid-cartilage_id
#       📏 Shape: ()
#       🔢 Type: int64
#       📋 Values: 0
#     📊 Dataset: 02072025/frame_0001/arytenoid-cartilage_mask
#       📏 Shape: (480, 480)
#       🔢 Type: uint8
#     📊 Dataset: 02072025/frame_0001/background_bbox
#       📏 Shape: (4,)
#       🔢 Type: int64
#       📋 Values: [  0   0 479 479]
#     📊 Dataset: 02072025/frame_0001/background_contour
#       📏 Shape: (264, 2)
#       🔢 Type: int64
#     📊 Dataset: 02072025/frame_0001/background_id
#       📏 Shape: ()
#       🔢 Type: int64
#       📋 Values: 1
#     📊 Dataset: 02072025/frame_0001/background_mask
#       📏 Shape: (480, 480)
#       🔢 Type: uint8
#     📊 Dataset: 02072025/frame_0001/brain-stem_bbox
#       📏 Shape: (4,)
#       🔢 Type: int64
#       📋 Values: [308  12  94 203]
#     📊 Dataset: 02072025/frame_0001/brain-stem_contour
#       📏 Shape: (50, 2)
#       🔢 Type: int64
#       📋 Sample: [373  24]
#     📊 Dataset: 02072025/frame_0001/brain-stem_id
#       📏 Shape: ()
#       🔢 Type: int64
#       📋 Values: 2
#     📊 Dataset: 02072025/frame_0001/brain-stem_mask
#       📏 Shape: (480, 480)
#       🔢 Type: uint8
#     📊 Dataset: 02072025/frame_0001/c1_bbox
#       📏 Shape: (4,)
#       🔢 Type: int64
#       📋 Values: [296 200  24  41]
#     📊 Dataset: 02072025/frame_0001/c1_contour
#       📏 Shape: (17, 2)
#       🔢 Type: int64
#       📋 Sample: [312 201]
#     📊 Dataset: 02072025/frame_0001/c1_id
#       📏 Shape: ()
#       🔢 Type: int64
#       📋 Values: 3
#     📊 Dataset: 02072025/frame_0001/c1_mask
#       📏 Shape: (480, 480)
#       🔢 Type: uint8
#     📊 Dataset: 02072025/frame_0001/c2_bbox
#       📏 Shape: (4,)
#       🔢 Type: int64
#       📋 Values: [297 207  42  94]
#     📊 Dataset: 02072025/frame_0001/c2_contour
#       📏 Shape: (20, 2)
#       🔢 Type: int64
#       📋 Sample: [310 239]
#     📊 Dataset: 02072025/frame_0001/c2_id
#       📏 Shape: ()
#       🔢 Type: int64
#       📋 Values: 4
#     📊 Dataset: 02072025/frame_0001/c2_mask
#       📏 Shape: (480, 480)
#       🔢 Type: uint8
#     📊 Dataset: 02072025/frame_0001/c3_bbox
#       📏 Shape: (4,)
#       🔢 Type: int64
#       📋 Values: [299 305  39  38]
#     📊 Dataset: 02072025/frame_0001/c3_contour
#       📏 Shape: (20, 2)
#       🔢 Type: int64
#       📋 Sample: [302 314]
#     📊 Dataset: 02072025/frame_0001/c3_id
#       📏 Shape: ()
#       🔢 Type: int64
#       📋 Values: 5
#     📊 Dataset: 02072025/frame_0001/c3_mask
#       📏 Shape: (480, 480)
#       🔢 Type: uint8
#     📊 Dataset: 02072025/frame_0001/c4_bbox
#       📏 Shape: (4,)
#       🔢 Type: int64
#       📋 Values: [305 344  38  33]
#     📊 Dataset: 02072025/frame_0001/c4_contour
#       📏 Shape: (20, 2)
#       🔢 Type: int64
#       📋 Sample: [307 354]
#     📊 Dataset: 02072025/frame_0001/c4_id
#       📏 Shape: ()
#       🔢 Type: int64
#       📋 Values: 6
#     📊 Dataset: 02072025/frame_0001/c4_mask
#       📏 Shape: (480, 480)
#       🔢 Type: uint8
#     📊 Dataset: 02072025/frame_0001/c5_bbox
#       📏 Shape: (4,)
#       🔢 Type: int64
#       📋 Values: [313 384  37  31]
#     📊 Dataset: 02072025/frame_0001/c5_contour
#       📏 Shape: (20, 2)
#       🔢 Type: int64
#       📋 Sample: [316 390]
#     📊 Dataset: 02072025/frame_0001/c5_id
#       📏 Shape: ()
#       🔢 Type: int64
#       📋 Values: 7
#     📊 Dataset: 02072025/frame_0001/c5_mask
#       📏 Shape: (480, 480)
#       🔢 Type: uint8
#     📊 Dataset: 02072025/frame_0001/c6_bbox
#       📏 Shape: (4,)
#       🔢 Type: int64
#       📋 Values: [313 422  39  31]
#     📊 Dataset: 02072025/frame_0001/c6_contour
#       📏 Shape: (20, 2)
#       🔢 Type: int64
#       📋 Sample: [318 426]
#     📊 Dataset: 02072025/frame_0001/c6_id
#       📏 Shape: ()
#       🔢 Type: int64
#       📋 Values: 8
#     📊 Dataset: 02072025/frame_0001/c6_mask
#       📏 Shape: (480, 480)
#       🔢 Type: uint8
#     📊 Dataset: 02072025/frame_0001/cerebellum_bbox
#       📏 Shape: (4,)
#       🔢 Type: int64
#       📋 Values: [380  85  95 137]
#     📊 Dataset: 02072025/frame_0001/cerebellum_contour
#       📏 Shape: (50, 2)
#       🔢 Type: int64
#       📋 Sample: [397 118]
#     📊 Dataset: 02072025/frame_0001/cerebellum_id
#       📏 Shape: ()
#       🔢 Type: int64
#       📋 Values: 9
#     📊 Dataset: 02072025/frame_0001/cerebellum_mask
#       📏 Shape: (480, 480)
#       🔢 Type: uint8
#     📊 Dataset: 02072025/frame_0001/chin_bbox
#       📏 Shape: (4,)
#       🔢 Type: int64
#       📋 Values: [ 78 327  72  57]
#     📊 Dataset: 02072025/frame_0001/chin_contour
#       📏 Shape: (40, 2)
#       🔢 Type: int64
#       📋 Sample: [ 78 327]
#     📊 Dataset: 02072025/frame_0001/chin_id
#       📏 Shape: ()
#       🔢 Type: int64
#       📋 Values: 10
#     📊 Dataset: 02072025/frame_0001/chin_mask
#       📏 Shape: (480, 480)
#       🔢 Type: uint8
#     📊 Dataset: 02072025/frame_0001/epiglottis_bbox
#       📏 Shape: (4,)
#       🔢 Type: int64
#       📋 Values: [239 329  40  58]
#     📊 Dataset: 02072025/frame_0001/epiglottis_contour
#       📏 Shape: (20, 2)
#       🔢 Type: int64
#       📋 Sample: [279 329]
#     📊 Dataset: 02072025/frame_0001/epiglottis_id
#       📏 Shape: ()
#       🔢 Type: int64
#       📋 Values: 11
#     📊 Dataset: 02072025/frame_0001/epiglottis_mask
#       📏 Shape: (480, 480)
#       🔢 Type: uint8
#     📊 Dataset: 02072025/frame_0001/frontal-sinus_bbox
#       📏 Shape: (4,)
#       🔢 Type: int64
#       📋 Values: [128   6  42  55]
#     📊 Dataset: 02072025/frame_0001/frontal-sinus_contour
#       📏 Shape: (40, 2)
#       🔢 Type: int64
#       📋 Sample: [131   6]
#     📊 Dataset: 02072025/frame_0001/frontal-sinus_id
#       📏 Shape: ()
#       🔢 Type: int64
#       📋 Values: 12
#     📊 Dataset: 02072025/frame_0001/frontal-sinus_mask
#       📏 Shape: (480, 480)
#       🔢 Type: uint8
#     📊 Dataset: 02072025/frame_0001/geniohyoid-muscle_bbox
#       📏 Shape: (4,)
#       🔢 Type: int64
#       📋 Values: [141 324  88  33]
#     📊 Dataset: 02072025/frame_0001/geniohyoid-muscle_contour
#       📏 Shape: (41, 2)
#       🔢 Type: int64
#       📋 Sample: [229 338]
#     📊 Dataset: 02072025/frame_0001/geniohyoid-muscle_id
#       📏 Shape: ()
#       🔢 Type: int64
#       📋 Values: 13
#     📊 Dataset: 02072025/frame_0001/geniohyoid-muscle_mask
#       📏 Shape: (480, 480)
#       🔢 Type: uint8
#     📊 Dataset: 02072025/frame_0001/head_bbox
#       📏 Shape: (4,)
#       🔢 Type: int64
#       📋 Values: [ 34   6 445 473]
#     📊 Dataset: 02072025/frame_0001/head_contour
#       📏 Shape: (264, 2)
#       🔢 Type: int64
#     📊 Dataset: 02072025/frame_0001/head_id
#       📏 Shape: ()
#       🔢 Type: int64
#       📋 Values: 14
#     📊 Dataset: 02072025/frame_0001/head_mask
#       📏 Shape: (480, 480)
#       🔢 Type: uint8
#     📊 Dataset: 02072025/frame_0001/hyoid_bbox
#       📏 Shape: (4,)
#       🔢 Type: int64
#       📋 Values: [229 336  15  15]
#     📊 Dataset: 02072025/frame_0001/hyoid_contour
#       📏 Shape: (25, 2)
#       🔢 Type: int64
#       📋 Sample: [240 336]
#     📊 Dataset: 02072025/frame_0001/hyoid_id
#       📏 Shape: ()
#       🔢 Type: int64
#       📋 Values: 15
#     📊 Dataset: 02072025/frame_0001/hyoid_mask
#       📏 Shape: (480, 480)
#       🔢 Type: uint8
#     📊 Dataset: 02072025/frame_0001/image
#       📏 Shape: (480, 480)
#       🔢 Type: uint8
#     📊 Dataset: 02072025/frame_0001/image_rgb
#       📏 Shape: (480, 480, 3)
#       🔢 Type: uint8
#     📊 Dataset: 02072025/frame_0001/incisior-hard-palate_bbox
#       📏 Shape: (4,)
#       🔢 Type: int64
#       📋 Values: [ 72 177 115  76]
#     📊 Dataset: 02072025/frame_0001/incisior-hard-palate_contour
#       📏 Shape: (40, 2)
#       🔢 Type: int64
#       📋 Sample: [103 177]
#     📊 Dataset: 02072025/frame_0001/incisior-hard-palate_id
#       📏 Shape: ()
#       🔢 Type: int64
#       📋 Values: 16
#     📊 Dataset: 02072025/frame_0001/incisior-hard-palate_mask
#       📏 Shape: (480, 480)
#       🔢 Type: uint8
#     📊 Dataset: 02072025/frame_0001/lower-lip_bbox
#       📏 Shape: (4,)
#       🔢 Type: int64
#       📋 Values: [ 57 255  55  59]
#     📊 Dataset: 02072025/frame_0001/lower-lip_contour
#       📏 Shape: (30, 2)
#       🔢 Type: int64
#       📋 Sample: [112 314]
#     📊 Dataset: 02072025/frame_0001/lower-lip_id
#       📏 Shape: ()
#       🔢 Type: int64
#       📋 Values: 17
#     📊 Dataset: 02072025/frame_0001/lower-lip_mask
#       📏 Shape: (480, 480)
#       🔢 Type: uint8
#     📊 Dataset: 02072025/frame_0001/mandible-incisior_bbox
#       📏 Shape: (4,)
#       🔢 Type: int64
#       📋 Values: [ 86 265  59  96]
#     📊 Dataset: 02072025/frame_0001/mandible-incisior_contour
#       📏 Shape: (40, 2)
#       🔢 Type: int64
#       📋 Sample: [ 86 266]
#     📊 Dataset: 02072025/frame_0001/mandible-incisior_id
#       📏 Shape: ()
#       🔢 Type: int64
#       📋 Values: 18
#     📊 Dataset: 02072025/frame_0001/mandible-incisior_mask
#       📏 Shape: (480, 480)
#       🔢 Type: uint8
#     📊 Dataset: 02072025/frame_0001/nasal-root_bbox
#       📏 Shape: (4,)
#       🔢 Type: int64
#       📋 Values: [98 33 13 42]
#     📊 Dataset: 02072025/frame_0001/nasal-root_contour
#       📏 Shape: (40, 2)
#       🔢 Type: int64
#       📋 Sample: [109  33]
#     📊 Dataset: 02072025/frame_0001/nasal-root_id
#       📏 Shape: ()
#       🔢 Type: int64
#       📋 Values: 19
#     📊 Dataset: 02072025/frame_0001/nasal-root_mask
#       📏 Shape: (480, 480)
#       🔢 Type: uint8
#     📊 Dataset: 02072025/frame_0001/nose-tip_bbox
#       📏 Shape: (4,)
#       🔢 Type: int64
#       📋 Values: [ 35 119  31  60]
#     📊 Dataset: 02072025/frame_0001/nose-tip_contour
#       📏 Shape: (40, 2)
#       🔢 Type: int64
#       📋 Sample: [ 56 119]
#     📊 Dataset: 02072025/frame_0001/nose-tip_id
#       📏 Shape: ()
#       🔢 Type: int64
#       📋 Values: 20
#     📊 Dataset: 02072025/frame_0001/nose-tip_mask
#       📏 Shape: (480, 480)
#       🔢 Type: uint8
#     📊 Dataset: 02072025/frame_0001/occipital-crest_bbox
#       📏 Shape: (4,)
#       🔢 Type: int64
#       📋 Values: [413 214  67  19]
#     📊 Dataset: 02072025/frame_0001/occipital-crest_contour
#       📏 Shape: (50, 2)
#       🔢 Type: int64
#       📋 Sample: [413 223]
#     📊 Dataset: 02072025/frame_0001/occipital-crest_id
#       📏 Shape: ()
#       🔢 Type: int64
#       📋 Values: 21
#     📊 Dataset: 02072025/frame_0001/occipital-crest_mask
#       📏 Shape: (480, 480)
#       🔢 Type: uint8
#     📊 Dataset: 02072025/frame_0001/pharynx_bbox
#       📏 Shape: (4,)
#       🔢 Type: int64
#       📋 Values: [274 179  22 179]
#     📊 Dataset: 02072025/frame_0001/pharynx_contour
#       📏 Shape: (35, 2)
#       🔢 Type: int64
#       📋 Sample: [274 179]
#     📊 Dataset: 02072025/frame_0001/pharynx_id
#       📏 Shape: ()
#       🔢 Type: int64
#       📋 Values: 22
#     📊 Dataset: 02072025/frame_0001/pharynx_mask
#       📏 Shape: (480, 480)
#       🔢 Type: uint8
#     📊 Dataset: 02072025/frame_0001/sample_data
#       📏 Shape: ()
#       🔢 Type: object
#       📋 Values: b'{"filepath": "/home/pyuser/data/RealTimeSwallowing/2017-110^01-0196-V1MR/OTHER/S7/RoiFig_vt_b/Frames/frame_frame_0001_2017-110^01-0196-V1MR_Serie_7.png", "tags": [], "metadata": null, "created_at": {"$date": "2025-07-02T10:18:47.599Z"}, "last_modified_at": {"$date": "2025-07-02T10:18:47.599Z"}, "index_image": 1, "Serie": "7", "Patient": "2017-110^01-0196-V1MR", "ground_truth": {"_cls": "DynamicEmbeddedDocument", "articulator_classifications": {"_cls": "Classifications", "classifications": [{"_id": {"$oid": "68650787ef85aeb5e83cb61c"}, "_cls": "Classification", "tags": [], "label": "arytenoid-cartilage"}, {"_id": {"$oid": "68650787ef85aeb5e83cb61f"}, "_cls": "Classification", "tags": [], "label": "background"}, {"_id": {"$oid": "68650787ef85aeb5e83cb622"}, "_cls": "Classification", "tags": [], "label": "brain-stem"}, {"_id": {"$oid": "68650787ef85aeb5e83cb625"}, "_cls": "Classification", "tags": [], "label": "c1"}, {"_id": {"$oid": "68650787ef85aeb5e83cb628"}, "_cls": "Classification", "tags": [], "label": "c2"}, {"_id": {"$oid": "68650787ef85aeb5e83cb62b"}, "_cls": "Classification", "tags": [], "label": "c3"}, {"_id": {"$oid": "68650787ef85aeb5e83cb62e"}, "_cls": "Classification", "tags": [], "label": "c4"}, {"_id": {"$oid": "68650787ef85aeb5e83cb631"}, "_cls": "Classification", "tags": [], "label": "c5"}, {"_id": {"$oid": "68650787ef85aeb5e83cb634"}, "_cls": "Classification", "tags": [], "label": "c6"}, {"_id": {"$oid": "68650787ef85aeb5e83cb637"}, "_cls": "Classification", "tags": [], "label": "cerebellum"}, {"_id": {"$oid": "68650787ef85aeb5e83cb63a"}, "_cls": "Classification", "tags": [], "label": "chin"}, {"_id": {"$oid": "68650787ef85aeb5e83cb63d"}, "_cls": "Classification", "tags": [], "label": "epiglottis"}, {"_id": {"$oid": "68650787ef85aeb5e83cb640"}, "_cls": "Classification", "tags": [], "label": "frontal-sinus"}, {"_id": {"$oid": "68650787ef85aeb5e83cb643"}, "_cls": "Classification", "tags": [], "label": "geniohyoid-muscle"}, {"_id": {"$oid": "68650787ef85aeb5e83cb646"}, "_cls": "Classification", "tags": [], "label": "head"}, {"_id": {"$oid": "68650787ef85aeb5e83cb649"}, "_cls": "Classification", "tags": [], "label": "hyoid"}, {"_id": {"$oid": "68650787ef85aeb5e83cb64c"}, "_cls": "Classification", "tags": [], "label": "incisior-hard-palate"}, {"_id": {"$oid": "68650787ef85aeb5e83cb64f"}, "_cls": "Classification", "tags": [], "label": "lower-lip"}, {"_id": {"$oid": "68650787ef85aeb5e83cb652"}, "_cls": "Classification", "tags": [], "label": "mandible-incisior"}, {"_id": {"$oid": "68650787ef85aeb5e83cb655"}, "_cls": "Classification", "tags": [], "label": "nasal-root"}, {"_id": {"$oid": "68650787ef85aeb5e83cb658"}, "_cls": "Classification", "tags": [], "label": "nose-tip"}, {"_id": {"$oid": "68650787ef85aeb5e83cb65b"}, "_cls": "Classification", "tags": [], "label": "occipital-crest"}, {"_id": {"$oid": "68650787ef85aeb5e83cb65e"}, "_cls": "Classification", "tags": [], "label": "pharynx"}, {"_id": {"$oid": "68650787ef85aeb5e83cb661"}, "_cls": "Classification", "tags": [], "label": "soft-palate"}, {"_id": {"$oid": "68650787ef85aeb5e83cb664"}, "_cls": "Classification", "tags": [], "label": "soft-palate-midline"}, {"_id": {"$oid": "68650787ef85aeb5e83cb667"}, "_cls": "Classification", "tags": [], "label": "sphenoid"}, {"_id": {"$oid": "68650787ef85aeb5e83cb66a"}, "_cls": "Classification", "tags": [], "label": "thyroid-cartilage"}, {"_id": {"$oid": "68650787ef85aeb5e83cb66d"}, "_cls": "Classification", "tags": [], "label": "tongue"}, {"_id": {"$oid": "68650787ef85aeb5e83cb670"}, "_cls": "Classification", "tags": [], "label": "tongue-and-floor"}, {"_id": {"$oid": "68650787ef85aeb5e83cb673"}, "_cls": "Classification", "tags": [], "label": "tongue-floor"}, {"_id": {"$oid": "68650787ef85aeb5e83cb676"}, "_cls": "Classification", "tags": [], "label": "tongue-muscle"}, {"_id": {"$oid": "68650787ef85aeb5e83cb679"}, "_cls": "Classification", "tags": [], "label": "upper-lip"}, {"_id": {"$oid": "68650787ef85aeb5e83cb6 ...
#     📊 Dataset: 02072025/frame_0001/soft-palate-midline_bbox
#       📏 Shape: (4,)
#       🔢 Type: int64
#       📋 Values: [179 199  85  64]
#     📊 Dataset: 02072025/frame_0001/soft-palate-midline_contour
#       📏 Shape: (20, 2)
#       🔢 Type: int64
#       📋 Sample: [179 199]
#     📊 Dataset: 02072025/frame_0001/soft-palate-midline_id
#       📏 Shape: ()
#       🔢 Type: int64
#       📋 Values: 24
#     📊 Dataset: 02072025/frame_0001/soft-palate-midline_mask
#       📏 Shape: (480, 480)
#       🔢 Type: uint8
#     📊 Dataset: 02072025/frame_0001/soft-palate_bbox
#       📏 Shape: (4,)
#       🔢 Type: int64
#       📋 Values: [176 197  92  67]
#     📊 Dataset: 02072025/frame_0001/soft-palate_contour
#       📏 Shape: (52, 2)
#       🔢 Type: int64
#       📋 Sample: [186 197]
#     📊 Dataset: 02072025/frame_0001/soft-palate_id
#       📏 Shape: ()
#       🔢 Type: int64
#       📋 Values: 23
#     📊 Dataset: 02072025/frame_0001/soft-palate_mask
#       📏 Shape: (480, 480)
#       🔢 Type: uint8
#     📊 Dataset: 02072025/frame_0001/sphenoid_bbox
#       📏 Shape: (4,)
#       🔢 Type: int64
#       📋 Values: [231  78 100 120]
#     📊 Dataset: 02072025/frame_0001/sphenoid_contour
#       📏 Shape: (35, 2)
#       🔢 Type: int64
#       📋 Sample: [237  78]
#     📊 Dataset: 02072025/frame_0001/sphenoid_id
#       📏 Shape: ()
#       🔢 Type: int64
#       📋 Values: 25
#     📊 Dataset: 02072025/frame_0001/sphenoid_mask
#       📏 Shape: (480, 480)
#       🔢 Type: uint8
#     📊 Dataset: 02072025/frame_0001/thyroid-cartilage_bbox
#       📏 Shape: (4,)
#       🔢 Type: int64
#       📋 Values: [230 385  15  31]
#     📊 Dataset: 02072025/frame_0001/thyroid-cartilage_contour
#       📏 Shape: (20, 2)
#       🔢 Type: int64
#       📋 Sample: [237 416]
#     📊 Dataset: 02072025/frame_0001/thyroid-cartilage_id
#       📏 Shape: ()
#       🔢 Type: int64
#       📋 Values: 26
#     📊 Dataset: 02072025/frame_0001/thyroid-cartilage_mask
#       📏 Shape: (480, 480)
#       🔢 Type: uint8
#     📊 Dataset: 02072025/frame_0001/tongue-and-floor_bbox
#       📏 Shape: (4,)
#       🔢 Type: int64
#       📋 Values: [ 77 197 193 160]
#     📊 Dataset: 02072025/frame_0001/tongue-and-floor_contour
#       📏 Shape: (247, 2)
#       🔢 Type: int64
#     📊 Dataset: 02072025/frame_0001/tongue-and-floor_id
#       📏 Shape: ()
#       🔢 Type: int64
#       📋 Values: 28
#     📊 Dataset: 02072025/frame_0001/tongue-and-floor_mask
#       📏 Shape: (480, 480)
#       🔢 Type: uint8
#     📊 Dataset: 02072025/frame_0001/tongue-floor_bbox
#       📏 Shape: (4,)
#       🔢 Type: int64
#       📋 Values: [139 357  84  15]
#     📊 Dataset: 02072025/frame_0001/tongue-floor_contour
#       📏 Shape: (40, 2)
#       🔢 Type: int64
#       📋 Sample: [139 362]
#     📊 Dataset: 02072025/frame_0001/tongue-floor_id
#       📏 Shape: ()
#       🔢 Type: int64
#       📋 Values: 29
#     📊 Dataset: 02072025/frame_0001/tongue-floor_mask
#       📏 Shape: (480, 480)
#       🔢 Type: uint8
#     📊 Dataset: 02072025/frame_0001/tongue-muscle_bbox
#       📏 Shape: (4,)
#       🔢 Type: int64
#       📋 Values: [ 77 197 193 142]
#     📊 Dataset: 02072025/frame_0001/tongue-muscle_contour
#       📏 Shape: (60, 2)
#       🔢 Type: int64
#       📋 Sample: [231 335]
#     📊 Dataset: 02072025/frame_0001/tongue-muscle_id
#       📏 Shape: ()
#       🔢 Type: int64
#       📋 Values: 30
#     📊 Dataset: 02072025/frame_0001/tongue-muscle_mask
#       📏 Shape: (480, 480)
#       🔢 Type: uint8
#     📊 Dataset: 02072025/frame_0001/tongue_bbox
#       📏 Shape: (4,)
#       🔢 Type: int64
#       📋 Values: [ 77 197 193 142]
#     📊 Dataset: 02072025/frame_0001/tongue_contour
#       📏 Shape: (60, 2)
#       🔢 Type: int64
#       📋 Sample: [231 335]
#     📊 Dataset: 02072025/frame_0001/tongue_id
#       📏 Shape: ()
#       🔢 Type: int64
#       📋 Values: 27
#     📊 Dataset: 02072025/frame_0001/tongue_mask
#       📏 Shape: (480, 480)
#       🔢 Type: uint8
#     📊 Dataset: 02072025/frame_0001/upper-lip_bbox
#       📏 Shape: (4,)
#       🔢 Type: int64
#       📋 Values: [ 50 190  40  63]
#     📊 Dataset: 02072025/frame_0001/upper-lip_contour
#       📏 Shape: (30, 2)
#       🔢 Type: int64
#       📋 Sample: [ 65 190]
#     📊 Dataset: 02072025/frame_0001/upper-lip_id
#       📏 Shape: ()
#       🔢 Type: int64
#       📋 Values: 31
#     📊 Dataset: 02072025/frame_0001/upper-lip_mask
#       📏 Shape: (480, 480)
#       🔢 Type: uint8
#     📊 Dataset: 02072025/frame_0001/vocal-folds_bbox
#       📏 Shape: (4,)
#       🔢 Type: int64
#       📋 Values: [245 392  30  13]
#     📊 Dataset: 02072025/frame_0001/vocal-folds_contour
#       📏 Shape: (20, 2)
#       🔢 Type: int64
#       📋 Sample: [263 403]
#     📊 Dataset: 02072025/frame_0001/vocal-folds_id
#       📏 Shape: ()
#       🔢 Type: int64
#       📋 Values: 32
#     📊 Dataset: 02072025/frame_0001/vocal-folds_mask
#       📏 Shape: (480, 480)
#       🔢 Type: uint8
#     📊 Dataset: 02072025/frame_0001/vocal-track_bbox
#       📏 Shape: (4,)
#       🔢 Type: int64
#       📋 Values: [171 158 124 236]
#     📊 Dataset: 02072025/frame_0001/vocal-track_contour
#       📏 Shape: (47, 2)
#       🔢 Type: int64
#       📋 Sample: [240 174]
#     📊 Dataset: 02072025/frame_0001/vocal-track_id
#       📏 Shape: ()
#       🔢 Type: int64
#       📋 Values: 33
#     📊 Dataset: 02072025/frame_0001/vocal-track_mask
#       📏 Shape: (480, 480)
#       🔢 Type: uint8
#   📁 Group: 02072025/frame_0217
#     📊 Dataset: 02072025/frame_0217/arytenoid-cartilage_bbox
#       📏 Shape: (4,)
#       🔢 Type: int64
#       📋 Values: [270 357  26  41]
#     📊 Dataset: 02072025/frame_0217/arytenoid-cartilage_contour
#       📏 Shape: (23, 2)
#       🔢 Type: int64
#       📋 Sample: [295 357]
#     📊 Dataset: 02072025/frame_0217/arytenoid-cartilage_id
#       📏 Shape: ()
#       🔢 Type: int64
#       📋 Values: 0
#     📊 Dataset: 02072025/frame_0217/arytenoid-cartilage_mask
#       📏 Shape: (480, 480)
#       🔢 Type: uint8
#     📊 Dataset: 02072025/frame_0217/background_bbox
#       📏 Shape: (4,)
#       🔢 Type: int64
#       📋 Values: [  0   0 479 479]
#     📊 Dataset: 02072025/frame_0217/background_contour
#       📏 Shape: (282, 2)
#       🔢 Type: int64
#     📊 Dataset: 02072025/frame_0217/background_id
#       📏 Shape: ()
#       🔢 Type: int64
#       📋 Values: 1
#     📊 Dataset: 02072025/frame_0217/background_mask
#       📏 Shape: (480, 480)
#       🔢 Type: uint8
#     📊 Dataset: 02072025/frame_0217/brain-stem_bbox
#       📏 Shape: (4,)
#       🔢 Type: int64
#       📋 Values: [307  16  91 204]
#     📊 Dataset: 02072025/frame_0217/brain-stem_contour
#       📏 Shape: (50, 2)
#       🔢 Type: int64
#       📋 Sample: [373  27]
#     📊 Dataset: 02072025/frame_0217/brain-stem_id
#       📏 Shape: ()
#       🔢 Type: int64
#       📋 Values: 2
#     📊 Dataset: 02072025/frame_0217/brain-stem_mask
#       📏 Shape: (480, 480)
#       🔢 Type: uint8
#     📊 Dataset: 02072025/frame_0217/c1_bbox
#       📏 Shape: (4,)
#       🔢 Type: int64
#       📋 Values: [298 199  24  42]
#     📊 Dataset: 02072025/frame_0217/c1_contour
#       📏 Shape: (19, 2)
#       🔢 Type: int64
#       📋 Sample: [314 199]
#     📊 Dataset: 02072025/frame_0217/c1_id
#       📏 Shape: ()
#       🔢 Type: int64
#       📋 Values: 3
#     📊 Dataset: 02072025/frame_0217/c1_mask
#       📏 Shape: (480, 480)
#       🔢 Type: uint8
#     📊 Dataset: 02072025/frame_0217/c2_bbox
#       📏 Shape: (4,)
#       🔢 Type: int64
#       📋 Values: [297 207  42  94]
#     📊 Dataset: 02072025/frame_0217/c2_contour
#       📏 Shape: (20, 2)
#       🔢 Type: int64
#       📋 Sample: [309 243]
#     📊 Dataset: 02072025/frame_0217/c2_id
#       📏 Shape: ()
#       🔢 Type: int64
#       📋 Values: 4
#     📊 Dataset: 02072025/frame_0217/c2_mask
#       📏 Shape: (480, 480)
#       🔢 Type: uint8
#     📊 Dataset: 02072025/frame_0217/c3_bbox
#       📏 Shape: (4,)
#       🔢 Type: int64
#       📋 Values: [299 304  39  38]
#     📊 Dataset: 02072025/frame_0217/c3_contour
#       📏 Shape: (20, 2)
#       🔢 Type: int64
#       📋 Sample: [302 313]
#     📊 Dataset: 02072025/frame_0217/c3_id
#       📏 Shape: ()
#       🔢 Type: int64
#       📋 Values: 5
#     📊 Dataset: 02072025/frame_0217/c3_mask
#       📏 Shape: (480, 480)
#       🔢 Type: uint8
#     📊 Dataset: 02072025/frame_0217/c4_bbox
#       📏 Shape: (4,)
#       🔢 Type: int64
#       📋 Values: [305 344  38  33]
#     📊 Dataset: 02072025/frame_0217/c4_contour
#       📏 Shape: (20, 2)
#       🔢 Type: int64
#       📋 Sample: [307 354]
#     📊 Dataset: 02072025/frame_0217/c4_id
#       📏 Shape: ()
#       🔢 Type: int64
#       📋 Values: 6
#     📊 Dataset: 02072025/frame_0217/c4_mask
#       📏 Shape: (480, 480)
#       🔢 Type: uint8
#     📊 Dataset: 02072025/frame_0217/c5_bbox
#       📏 Shape: (4,)
#       🔢 Type: int64
#       📋 Values: [313 384  37  30]
#     📊 Dataset: 02072025/frame_0217/c5_contour
#       📏 Shape: (20, 2)
#       🔢 Type: int64
#       📋 Sample: [316 390]
#     📊 Dataset: 02072025/frame_0217/c5_id
#       📏 Shape: ()
#       🔢 Type: int64
#       📋 Values: 7
#     📊 Dataset: 02072025/frame_0217/c5_mask
#       📏 Shape: (480, 480)
#       🔢 Type: uint8
#     📊 Dataset: 02072025/frame_0217/c6_bbox
#       📏 Shape: (4,)
#       🔢 Type: int64
#       📋 Values: [313 422  39  31]
#     📊 Dataset: 02072025/frame_0217/c6_contour
#       📏 Shape: (20, 2)
#       🔢 Type: int64
#       📋 Sample: [318 426]
#     📊 Dataset: 02072025/frame_0217/c6_id
#       📏 Shape: ()
#       🔢 Type: int64
#       📋 Values: 8
#     📊 Dataset: 02072025/frame_0217/c6_mask
#       📏 Shape: (480, 480)
#       🔢 Type: uint8
#     📊 Dataset: 02072025/frame_0217/cerebellum_bbox
#       📏 Shape: (4,)
#       🔢 Type: int64
#       📋 Values: [379  86  96 136]
#     📊 Dataset: 02072025/frame_0217/cerebellum_contour
#       📏 Shape: (50, 2)
#       🔢 Type: int64
#       📋 Sample: [394 119]
#     📊 Dataset: 02072025/frame_0217/cerebellum_id
#       📏 Shape: ()
#       🔢 Type: int64
#       📋 Values: 9
#     📊 Dataset: 02072025/frame_0217/cerebellum_mask
#       📏 Shape: (480, 480)
#       🔢 Type: uint8
#     📊 Dataset: 02072025/frame_0217/chin_bbox
#       📏 Shape: (4,)
#       🔢 Type: int64
#       📋 Values: [ 78 326  72  58]
#     📊 Dataset: 02072025/frame_0217/chin_contour
#       📏 Shape: (40, 2)
#       🔢 Type: int64
#       📋 Sample: [ 78 326]
#     📊 Dataset: 02072025/frame_0217/chin_id
#       📏 Shape: ()
#       🔢 Type: int64
#       📋 Values: 10
#     📊 Dataset: 02072025/frame_0217/chin_mask
#       📏 Shape: (480, 480)
#       🔢 Type: uint8
#     📊 Dataset: 02072025/frame_0217/epiglottis_bbox
#       📏 Shape: (4,)
#       🔢 Type: int64
#       📋 Values: [242 324  45  62]
#     📊 Dataset: 02072025/frame_0217/epiglottis_contour
#       📏 Shape: (20, 2)
#       🔢 Type: int64
#       📋 Sample: [287 324]
#     📊 Dataset: 02072025/frame_0217/epiglottis_id
#       📏 Shape: ()
#       🔢 Type: int64
#       📋 Values: 11
#     📊 Dataset: 02072025/frame_0217/epiglottis_mask
#       📏 Shape: (480, 480)
#       🔢 Type: uint8
#     📊 Dataset: 02072025/frame_0217/frontal-sinus_bbox
#       📏 Shape: (4,)
#       🔢 Type: int64
#       📋 Values: [128   6  45  56]
#     📊 Dataset: 02072025/frame_0217/frontal-sinus_contour
#       📏 Shape: (40, 2)
#       🔢 Type: int64
#       📋 Sample: [131   6]
#     📊 Dataset: 02072025/frame_0217/frontal-sinus_id
#       📏 Shape: ()
#       🔢 Type: int64
#       📋 Values: 12
#     📊 Dataset: 02072025/frame_0217/frontal-sinus_mask
#       📏 Shape: (480, 480)
#       🔢 Type: uint8
#     📊 Dataset: 02072025/frame_0217/geniohyoid-muscle_bbox
#       📏 Shape: (4,)
#       🔢 Type: int64
#       📋 Values: [141 328  89  28]
#     📊 Dataset: 02072025/frame_0217/geniohyoid-muscle_contour
#       📏 Shape: (41, 2)
#       🔢 Type: int64
#       📋 Sample: [230 336]
#     📊 Dataset: 02072025/frame_0217/geniohyoid-muscle_id
#       📏 Shape: ()
#       🔢 Type: int64
#       📋 Values: 13
#     📊 Dataset: 02072025/frame_0217/geniohyoid-muscle_mask
#       📏 Shape: (480, 480)
#       🔢 Type: uint8
#     📊 Dataset: 02072025/frame_0217/head_bbox
#       📏 Shape: (4,)
#       🔢 Type: int64
#       📋 Values: [ 35   6 444 473]
#     📊 Dataset: 02072025/frame_0217/head_contour
#       📏 Shape: (283, 2)
#       🔢 Type: int64
#     📊 Dataset: 02072025/frame_0217/head_id
#       📏 Shape: ()
#       🔢 Type: int64
#       📋 Values: 14
#     📊 Dataset: 02072025/frame_0217/head_mask
#       📏 Shape: (480, 480)
#       🔢 Type: uint8
#     📊 Dataset: 02072025/frame_0217/hyoid_bbox
#       📏 Shape: (4,)
#       🔢 Type: int64
#       📋 Values: [230 336  13  15]
#     📊 Dataset: 02072025/frame_0217/hyoid_contour
#       📏 Shape: (25, 2)
#       🔢 Type: int64
#       📋 Sample: [242 336]
#     📊 Dataset: 02072025/frame_0217/hyoid_id
#       📏 Shape: ()
#       🔢 Type: int64
#       📋 Values: 15
#     📊 Dataset: 02072025/frame_0217/hyoid_mask
#       📏 Shape: (480, 480)
#       🔢 Type: uint8
#     📊 Dataset: 02072025/frame_0217/image
#       📏 Shape: (480, 480)
#       🔢 Type: uint8
#     📊 Dataset: 02072025/frame_0217/image_rgb
#       📏 Shape: (480, 480, 3)
#       🔢 Type: uint8
#     📊 Dataset: 02072025/frame_0217/incisior-hard-palate_bbox
#       📏 Shape: (4,)
#       🔢 Type: int64
#       📋 Values: [ 72 177 113  75]
#     📊 Dataset: 02072025/frame_0217/incisior-hard-palate_contour
#       📏 Shape: (40, 2)
#       🔢 Type: int64
#       📋 Sample: [106 178]
#     📊 Dataset: 02072025/frame_0217/incisior-hard-palate_id
#       📏 Shape: ()
#       🔢 Type: int64
#       📋 Values: 16
#     📊 Dataset: 02072025/frame_0217/incisior-hard-palate_mask
#       📏 Shape: (480, 480)
#       🔢 Type: uint8
#     📊 Dataset: 02072025/frame_0217/lower-lip_bbox
#       📏 Shape: (4,)
#       🔢 Type: int64
#       📋 Values: [ 53 255  60  53]
#     📊 Dataset: 02072025/frame_0217/lower-lip_contour
#       📏 Shape: (30, 2)
#       🔢 Type: int64
#       📋 Sample: [113 307]
#     📊 Dataset: 02072025/frame_0217/lower-lip_id
#       📏 Shape: ()
#       🔢 Type: int64
#       📋 Values: 17
#     📊 Dataset: 02072025/frame_0217/lower-lip_mask
#       📏 Shape: (480, 480)
#       🔢 Type: uint8
#     📊 Dataset: 02072025/frame_0217/mandible-incisior_bbox
#       📏 Shape: (4,)
#       🔢 Type: int64
#       📋 Values: [ 84 264  60  97]
#     📊 Dataset: 02072025/frame_0217/mandible-incisior_contour
#       📏 Shape: (40, 2)
#       🔢 Type: int64
#       📋 Sample: [ 84 265]
#     📊 Dataset: 02072025/frame_0217/mandible-incisior_id
#       📏 Shape: ()
#       🔢 Type: int64
#       📋 Values: 18
#     📊 Dataset: 02072025/frame_0217/mandible-incisior_mask
#       📏 Shape: (480, 480)
#       🔢 Type: uint8
#     📊 Dataset: 02072025/frame_0217/nasal-root_bbox
#       📏 Shape: (4,)
#       🔢 Type: int64
#       📋 Values: [98 34 13 42]
#     📊 Dataset: 02072025/frame_0217/nasal-root_contour
#       📏 Shape: (40, 2)
#       🔢 Type: int64
#       📋 Sample: [109  34]
#     📊 Dataset: 02072025/frame_0217/nasal-root_id
#       📏 Shape: ()
#       🔢 Type: int64
#       📋 Values: 19
#     📊 Dataset: 02072025/frame_0217/nasal-root_mask
#       📏 Shape: (480, 480)
#       🔢 Type: uint8
#     📊 Dataset: 02072025/frame_0217/nose-tip_bbox
#       📏 Shape: (4,)
#       🔢 Type: int64
#       📋 Values: [ 36 120  31  60]
#     📊 Dataset: 02072025/frame_0217/nose-tip_contour
#       📏 Shape: (40, 2)
#       🔢 Type: int64
#       📋 Sample: [ 57 120]
#     📊 Dataset: 02072025/frame_0217/nose-tip_id
#       📏 Shape: ()
#       🔢 Type: int64
#       📋 Values: 20
#     📊 Dataset: 02072025/frame_0217/nose-tip_mask
#       📏 Shape: (480, 480)
#       🔢 Type: uint8
#     📊 Dataset: 02072025/frame_0217/occipital-crest_bbox
#       📏 Shape: (4,)
#       🔢 Type: int64
#       📋 Values: [413 214  67  19]
#     📊 Dataset: 02072025/frame_0217/occipital-crest_contour
#       📏 Shape: (50, 2)
#       🔢 Type: int64
#       📋 Sample: [413 223]
#     📊 Dataset: 02072025/frame_0217/occipital-crest_id
#       📏 Shape: ()
#       🔢 Type: int64
#       📋 Values: 21
#     📊 Dataset: 02072025/frame_0217/occipital-crest_mask
#       📏 Shape: (480, 480)
#       🔢 Type: uint8
#     📊 Dataset: 02072025/frame_0217/pharynx_bbox
#       📏 Shape: (4,)
#       🔢 Type: int64
#       📋 Values: [272 174  22 182]
#     📊 Dataset: 02072025/frame_0217/pharynx_contour
#       📏 Shape: (35, 2)
#       🔢 Type: int64
#       📋 Sample: [272 174]
#     📊 Dataset: 02072025/frame_0217/pharynx_id
#       📏 Shape: ()
#       🔢 Type: int64
#       📋 Values: 22
#     📊 Dataset: 02072025/frame_0217/pharynx_mask
#       📏 Shape: (480, 480)
#       🔢 Type: uint8
#     📊 Dataset: 02072025/frame_0217/sample_data
#       📏 Shape: ()
#       🔢 Type: object
#       📋 Values: b'{"filepath": "/home/pyuser/data/RealTimeSwallowing/2017-110^01-0196-V1MR/OTHER/S7/RoiFig_vt_b/Frames/frame_frame_0217_2017-110^01-0196-V1MR_Serie_7.png", "tags": [], "metadata": null, "created_at": {"$date": "2025-07-02T10:18:48.438Z"}, "last_modified_at": {"$date": "2025-07-02T10:18:48.438Z"}, "index_image": 217, "Serie": "7", "Patient": "2017-110^01-0196-V1MR", "ground_truth": {"_cls": "DynamicEmbeddedDocument", "articulator_classifications": {"_cls": "Classifications", "classifications": [{"_id": {"$oid": "68650788ef85aeb5e83cb683"}, "_cls": "Classification", "tags": [], "label": "arytenoid-cartilage"}, {"_id": {"$oid": "68650788ef85aeb5e83cb686"}, "_cls": "Classification", "tags": [], "label": "background"}, {"_id": {"$oid": "68650788ef85aeb5e83cb689"}, "_cls": "Classification", "tags": [], "label": "brain-stem"}, {"_id": {"$oid": "68650788ef85aeb5e83cb68c"}, "_cls": "Classification", "tags": [], "label": "c1"}, {"_id": {"$oid": "68650788ef85aeb5e83cb68f"}, "_cls": "Classification", "tags": [], "label": "c2"}, {"_id": {"$oid": "68650788ef85aeb5e83cb692"}, "_cls": "Classification", "tags": [], "label": "c3"}, {"_id": {"$oid": "68650788ef85aeb5e83cb695"}, "_cls": "Classification", "tags": [], "label": "c4"}, {"_id": {"$oid": "68650788ef85aeb5e83cb698"}, "_cls": "Classification", "tags": [], "label": "c5"}, {"_id": {"$oid": "68650788ef85aeb5e83cb69b"}, "_cls": "Classification", "tags": [], "label": "c6"}, {"_id": {"$oid": "68650788ef85aeb5e83cb69e"}, "_cls": "Classification", "tags": [], "label": "cerebellum"}, {"_id": {"$oid": "68650788ef85aeb5e83cb6a1"}, "_cls": "Classification", "tags": [], "label": "chin"}, {"_id": {"$oid": "68650788ef85aeb5e83cb6a4"}, "_cls": "Classification", "tags": [], "label": "epiglottis"}, {"_id": {"$oid": "68650788ef85aeb5e83cb6a7"}, "_cls": "Classification", "tags": [], "label": "frontal-sinus"}, {"_id": {"$oid": "68650788ef85aeb5e83cb6aa"}, "_cls": "Classification", "tags": [], "label": "geniohyoid-muscle"}, {"_id": {"$oid": "68650788ef85aeb5e83cb6ad"}, "_cls": "Classification", "tags": [], "label": "head"}, {"_id": {"$oid": "68650788ef85aeb5e83cb6b0"}, "_cls": "Classification", "tags": [], "label": "hyoid"}, {"_id": {"$oid": "68650788ef85aeb5e83cb6b3"}, "_cls": "Classification", "tags": [], "label": "incisior-hard-palate"}, {"_id": {"$oid": "68650788ef85aeb5e83cb6b6"}, "_cls": "Classification", "tags": [], "label": "lower-lip"}, {"_id": {"$oid": "68650788ef85aeb5e83cb6b9"}, "_cls": "Classification", "tags": [], "label": "mandible-incisior"}, {"_id": {"$oid": "68650788ef85aeb5e83cb6bc"}, "_cls": "Classification", "tags": [], "label": "nasal-root"}, {"_id": {"$oid": "68650788ef85aeb5e83cb6bf"}, "_cls": "Classification", "tags": [], "label": "nose-tip"}, {"_id": {"$oid": "68650788ef85aeb5e83cb6c2"}, "_cls": "Classification", "tags": [], "label": "occipital-crest"}, {"_id": {"$oid": "68650788ef85aeb5e83cb6c5"}, "_cls": "Classification", "tags": [], "label": "pharynx"}, {"_id": {"$oid": "68650788ef85aeb5e83cb6c8"}, "_cls": "Classification", "tags": [], "label": "soft-palate"}, {"_id": {"$oid": "68650788ef85aeb5e83cb6cb"}, "_cls": "Classification", "tags": [], "label": "soft-palate-midline"}, {"_id": {"$oid": "68650788ef85aeb5e83cb6ce"}, "_cls": "Classification", "tags": [], "label": "sphenoid"}, {"_id": {"$oid": "68650788ef85aeb5e83cb6d1"}, "_cls": "Classification", "tags": [], "label": "thyroid-cartilage"}, {"_id": {"$oid": "68650788ef85aeb5e83cb6d4"}, "_cls": "Classification", "tags": [], "label": "tongue"}, {"_id": {"$oid": "68650788ef85aeb5e83cb6d7"}, "_cls": "Classification", "tags": [], "label": "tongue-and-floor"}, {"_id": {"$oid": "68650788ef85aeb5e83cb6da"}, "_cls": "Classification", "tags": [], "label": "tongue-floor"}, {"_id": {"$oid": "68650788ef85aeb5e83cb6dd"}, "_cls": "Classification", "tags": [], "label": "tongue-muscle"}, {"_id": {"$oid": "68650788ef85aeb5e83cb6e0"}, "_cls": "Classification", "tags": [], "label": "upper-lip"}, {"_id": {"$oid": "68650788ef85aeb5e83c ...
#     📊 Dataset: 02072025/frame_0217/soft-palate-midline_bbox
#       📏 Shape: (4,)
#       🔢 Type: int64
#       📋 Values: [186 198  84  66]
#     📊 Dataset: 02072025/frame_0217/soft-palate-midline_contour
#       📏 Shape: (20, 2)
#       🔢 Type: int64
#       📋 Sample: [186 198]
#     📊 Dataset: 02072025/frame_0217/soft-palate-midline_id
#       📏 Shape: ()
#       🔢 Type: int64
#       📋 Values: 24
#     📊 Dataset: 02072025/frame_0217/soft-palate-midline_mask
#       📏 Shape: (480, 480)
#       🔢 Type: uint8
#     📊 Dataset: 02072025/frame_0217/soft-palate_bbox
#       📏 Shape: (4,)
#       🔢 Type: int64
#       📋 Values: [184 196  87  68]
#     📊 Dataset: 02072025/frame_0217/soft-palate_contour
#       📏 Shape: (41, 2)
#       🔢 Type: int64
#       📋 Sample: [187 196]
#     📊 Dataset: 02072025/frame_0217/soft-palate_id
#       📏 Shape: ()
#       🔢 Type: int64
#       📋 Values: 23
#     📊 Dataset: 02072025/frame_0217/soft-palate_mask
#       📏 Shape: (480, 480)
#       🔢 Type: uint8
#     📊 Dataset: 02072025/frame_0217/sphenoid_bbox
#       📏 Shape: (4,)
#       🔢 Type: int64
#       📋 Values: [226  76 103 120]
#     📊 Dataset: 02072025/frame_0217/sphenoid_contour
#       📏 Shape: (50, 2)
#       🔢 Type: int64
#       📋 Sample: [230  76]
#     📊 Dataset: 02072025/frame_0217/sphenoid_id
#       📏 Shape: ()
#       🔢 Type: int64
#       📋 Values: 25
#     📊 Dataset: 02072025/frame_0217/sphenoid_mask
#       📏 Shape: (480, 480)
#       🔢 Type: uint8
#     📊 Dataset: 02072025/frame_0217/thyroid-cartilage_bbox
#       📏 Shape: (4,)
#       🔢 Type: int64
#       📋 Values: [233 383  15  26]
#     📊 Dataset: 02072025/frame_0217/thyroid-cartilage_contour
#       📏 Shape: (20, 2)
#       🔢 Type: int64
#       📋 Sample: [244 409]
#     📊 Dataset: 02072025/frame_0217/thyroid-cartilage_id
#       📏 Shape: ()
#       🔢 Type: int64
#       📋 Values: 26
#     📊 Dataset: 02072025/frame_0217/thyroid-cartilage_mask
#       📏 Shape: (480, 480)
#       🔢 Type: uint8
#     📊 Dataset: 02072025/frame_0217/tongue-and-floor_bbox
#       📏 Shape: (4,)
#       🔢 Type: int64
#       📋 Values: [ 79 218 202 138]
#     📊 Dataset: 02072025/frame_0217/tongue-and-floor_contour
#       📏 Shape: (243, 2)
#       🔢 Type: int64
#     📊 Dataset: 02072025/frame_0217/tongue-and-floor_id
#       📏 Shape: ()
#       🔢 Type: int64
#       📋 Values: 28
#     📊 Dataset: 02072025/frame_0217/tongue-and-floor_mask
#       📏 Shape: (480, 480)
#       🔢 Type: uint8
#     📊 Dataset: 02072025/frame_0217/tongue-floor_bbox
#       📏 Shape: (4,)
#       🔢 Type: int64
#       📋 Values: [138 360  88  10]
#     📊 Dataset: 02072025/frame_0217/tongue-floor_contour
#       📏 Shape: (22, 2)
#       🔢 Type: int64
#       📋 Sample: [138 364]
#     📊 Dataset: 02072025/frame_0217/tongue-floor_id
#       📏 Shape: ()
#       🔢 Type: int64
#       📋 Values: 29
#     📊 Dataset: 02072025/frame_0217/tongue-floor_mask
#       📏 Shape: (480, 480)
#       🔢 Type: uint8
#     📊 Dataset: 02072025/frame_0217/tongue-muscle_bbox
#       📏 Shape: (4,)
#       🔢 Type: int64
#       📋 Values: [ 79 218 202 119]
#     📊 Dataset: 02072025/frame_0217/tongue-muscle_contour
#       📏 Shape: (55, 2)
#       🔢 Type: int64
#       📋 Sample: [146 327]
#     📊 Dataset: 02072025/frame_0217/tongue-muscle_id
#       📏 Shape: ()
#       🔢 Type: int64
#       📋 Values: 30
#     📊 Dataset: 02072025/frame_0217/tongue-muscle_mask
#       📏 Shape: (480, 480)
#       🔢 Type: uint8
#     📊 Dataset: 02072025/frame_0217/tongue_bbox
#       📏 Shape: (4,)
#       🔢 Type: int64
#       📋 Values: [ 79 218 202 119]
#     📊 Dataset: 02072025/frame_0217/tongue_contour
#       📏 Shape: (55, 2)
#       🔢 Type: int64
#       📋 Sample: [146 327]
#     📊 Dataset: 02072025/frame_0217/tongue_id
#       📏 Shape: ()
#       🔢 Type: int64
#       📋 Values: 27
#     📊 Dataset: 02072025/frame_0217/tongue_mask
#       📏 Shape: (480, 480)
#       🔢 Type: uint8
#     📊 Dataset: 02072025/frame_0217/upper-lip_bbox
#       📏 Shape: (4,)
#       🔢 Type: int64
#       📋 Values: [ 50 186  43  68]
#     📊 Dataset: 02072025/frame_0217/upper-lip_contour
#       📏 Shape: (30, 2)
#       🔢 Type: int64
#       📋 Sample: [ 67 186]
#     📊 Dataset: 02072025/frame_0217/upper-lip_id
#       📏 Shape: ()
#       🔢 Type: int64
#       📋 Values: 31
#     📊 Dataset: 02072025/frame_0217/upper-lip_mask
#       📏 Shape: (480, 480)
#       🔢 Type: uint8
#     📊 Dataset: 02072025/frame_0217/vocal-folds_bbox
#       📏 Shape: (4,)
#       🔢 Type: int64
#       📋 Values: [249 384  25  17]
#     📊 Dataset: 02072025/frame_0217/vocal-folds_contour
#       📏 Shape: (20, 2)
#       🔢 Type: int64
#       📋 Sample: [258 401]
#     📊 Dataset: 02072025/frame_0217/vocal-folds_id
#       📏 Shape: ()
#       🔢 Type: int64
#       📋 Values: 32
#     📊 Dataset: 02072025/frame_0217/vocal-folds_mask
#       📏 Shape: (480, 480)
#       🔢 Type: uint8
#     📊 Dataset: 02072025/frame_0217/vocal-track_bbox
#       📏 Shape: (4,)
#       🔢 Type: int64
#       📋 Values: [ 97 152 197 233]
#     📊 Dataset: 02072025/frame_0217/vocal-track_contour
#       📏 Shape: (61, 2)
#       🔢 Type: int64
#       📋 Sample: [270 384]
#     📊 Dataset: 02072025/frame_0217/vocal-track_id
#       📏 Shape: ()
#       🔢 Type: int64
#       📋 Values: 33
#     📊 Dataset: 02072025/frame_0217/vocal-track_mask
#       📏 Shape: (480, 480)
#       🔢 Type: uint8
#   📁 Group: 02072025/frame_0228
#     📊 Dataset: 02072025/frame_0228/arytenoid-cartilage_bbox
#       📏 Shape: (4,)
#       🔢 Type: int64
#       📋 Values: [263 355  33  33]
#     📊 Dataset: 02072025/frame_0228/arytenoid-cartilage_contour
#       📏 Shape: (26, 2)
#       🔢 Type: int64
#       📋 Sample: [295 355]
#     📊 Dataset: 02072025/frame_0228/arytenoid-cartilage_id
#       📏 Shape: ()
#       🔢 Type: int64
#       📋 Values: 0
#     📊 Dataset: 02072025/frame_0228/arytenoid-cartilage_mask
#       📏 Shape: (480, 480)
#       🔢 Type: uint8
#     📊 Dataset: 02072025/frame_0228/background_bbox
#       📏 Shape: (4,)
#       🔢 Type: int64
#       📋 Values: [  0   0 479 479]
#     📊 Dataset: 02072025/frame_0228/background_contour
#       📏 Shape: (245, 2)
#       🔢 Type: int64
#     📊 Dataset: 02072025/frame_0228/background_id
#       📏 Shape: ()
#       🔢 Type: int64
#       📋 Values: 1
#     📊 Dataset: 02072025/frame_0228/background_mask
#       📏 Shape: (480, 480)
#       🔢 Type: uint8
#     📊 Dataset: 02072025/frame_0228/brain-stem_bbox
#       📏 Shape: (4,)
#       🔢 Type: int64
#       📋 Values: [307  16  91 202]
#     📊 Dataset: 02072025/frame_0228/brain-stem_contour
#       📏 Shape: (50, 2)
#       🔢 Type: int64
#       📋 Sample: [376  24]
#     📊 Dataset: 02072025/frame_0228/brain-stem_id
#       📏 Shape: ()
#       🔢 Type: int64
#       📋 Values: 2
#     📊 Dataset: 02072025/frame_0228/brain-stem_mask
#       📏 Shape: (480, 480)
#       🔢 Type: uint8
#     📊 Dataset: 02072025/frame_0228/c1_bbox
#       📏 Shape: (4,)
#       🔢 Type: int64
#       📋 Values: [298 198  25  46]
#     📊 Dataset: 02072025/frame_0228/c1_contour
#       📏 Shape: (20, 2)
#       🔢 Type: int64
#       📋 Sample: [315 199]
#     📊 Dataset: 02072025/frame_0228/c1_id
#       📏 Shape: ()
#       🔢 Type: int64
#       📋 Values: 3
#     📊 Dataset: 02072025/frame_0228/c1_mask
#       📏 Shape: (480, 480)
#       🔢 Type: uint8
#     📊 Dataset: 02072025/frame_0228/c2_bbox
#       📏 Shape: (4,)
#       🔢 Type: int64
#       📋 Values: [297 207  42  94]
#     📊 Dataset: 02072025/frame_0228/c2_contour
#       📏 Shape: (20, 2)
#       🔢 Type: int64
#       📋 Sample: [310 238]
#     📊 Dataset: 02072025/frame_0228/c2_id
#       📏 Shape: ()
#       🔢 Type: int64
#       📋 Values: 4
#     📊 Dataset: 02072025/frame_0228/c2_mask
#       📏 Shape: (480, 480)
#       🔢 Type: uint8
#     📊 Dataset: 02072025/frame_0228/c3_bbox
#       📏 Shape: (4,)
#       🔢 Type: int64
#       📋 Values: [301 304  39  38]
#     📊 Dataset: 02072025/frame_0228/c3_contour
#       📏 Shape: (20, 2)
#       🔢 Type: int64
#       📋 Sample: [304 313]
#     📊 Dataset: 02072025/frame_0228/c3_id
#       📏 Shape: ()
#       🔢 Type: int64
#       📋 Values: 5
#     📊 Dataset: 02072025/frame_0228/c3_mask
#       📏 Shape: (480, 480)
#       🔢 Type: uint8
#     📊 Dataset: 02072025/frame_0228/c4_bbox
#       📏 Shape: (4,)
#       🔢 Type: int64
#       📋 Values: [305 344  38  33]
#     📊 Dataset: 02072025/frame_0228/c4_contour
#       📏 Shape: (20, 2)
#       🔢 Type: int64
#       📋 Sample: [307 354]
#     📊 Dataset: 02072025/frame_0228/c4_id
#       📏 Shape: ()
#       🔢 Type: int64
#       📋 Values: 6
#     📊 Dataset: 02072025/frame_0228/c4_mask
#       📏 Shape: (480, 480)
#       🔢 Type: uint8
#     📊 Dataset: 02072025/frame_0228/c5_bbox
#       📏 Shape: (4,)
#       🔢 Type: int64
#       📋 Values: [313 384  37  30]
#     📊 Dataset: 02072025/frame_0228/c5_contour
#       📏 Shape: (20, 2)
#       🔢 Type: int64
#       📋 Sample: [317 390]
#     📊 Dataset: 02072025/frame_0228/c5_id
#       📏 Shape: ()
#       🔢 Type: int64
#       📋 Values: 7
#     📊 Dataset: 02072025/frame_0228/c5_mask
#       📏 Shape: (480, 480)
#       🔢 Type: uint8
#     📊 Dataset: 02072025/frame_0228/c6_bbox
#       📏 Shape: (4,)
#       🔢 Type: int64
#       📋 Values: [313 422  39  31]
#     📊 Dataset: 02072025/frame_0228/c6_contour
#       📏 Shape: (20, 2)
#       🔢 Type: int64
#       📋 Sample: [318 426]
#     📊 Dataset: 02072025/frame_0228/c6_id
#       📏 Shape: ()
#       🔢 Type: int64
#       📋 Values: 8
#     📊 Dataset: 02072025/frame_0228/c6_mask
#       📏 Shape: (480, 480)
#       🔢 Type: uint8
#     📊 Dataset: 02072025/frame_0228/cerebellum_bbox
#       📏 Shape: (4,)
#       🔢 Type: int64
#       📋 Values: [380  87  95 134]
#     📊 Dataset: 02072025/frame_0228/cerebellum_contour
#       📏 Shape: (50, 2)
#       🔢 Type: int64
#       📋 Sample: [397 115]
#     📊 Dataset: 02072025/frame_0228/cerebellum_id
#       📏 Shape: ()
#       🔢 Type: int64
#       📋 Values: 9
#     📊 Dataset: 02072025/frame_0228/cerebellum_mask
#       📏 Shape: (480, 480)
#       🔢 Type: uint8
#     📊 Dataset: 02072025/frame_0228/chin_bbox
#       📏 Shape: (4,)
#       🔢 Type: int64
#       📋 Values: [ 79 327  71  58]
#     📊 Dataset: 02072025/frame_0228/chin_contour
#       📏 Shape: (40, 2)
#       🔢 Type: int64
#       📋 Sample: [ 79 327]
#     📊 Dataset: 02072025/frame_0228/chin_id
#       📏 Shape: ()
#       🔢 Type: int64
#       📋 Values: 10
#     📊 Dataset: 02072025/frame_0228/chin_mask
#       📏 Shape: (480, 480)
#       🔢 Type: uint8
#     📊 Dataset: 02072025/frame_0228/epiglottis_bbox
#       📏 Shape: (4,)
#       🔢 Type: int64
#       📋 Values: [243 318  40  66]
#     📊 Dataset: 02072025/frame_0228/epiglottis_contour
#       📏 Shape: (20, 2)
#       🔢 Type: int64
#       📋 Sample: [283 318]
#     📊 Dataset: 02072025/frame_0228/epiglottis_id
#       📏 Shape: ()
#       🔢 Type: int64
#       📋 Values: 11
#     📊 Dataset: 02072025/frame_0228/epiglottis_mask
#       📏 Shape: (480, 480)
#       🔢 Type: uint8
#     📊 Dataset: 02072025/frame_0228/frontal-sinus_bbox
#       📏 Shape: (4,)
#       🔢 Type: int64
#       📋 Values: [128   6  45  60]
#     📊 Dataset: 02072025/frame_0228/frontal-sinus_contour
#       📏 Shape: (40, 2)
#       🔢 Type: int64
#       📋 Sample: [131   6]
#     📊 Dataset: 02072025/frame_0228/frontal-sinus_id
#       📏 Shape: ()
#       🔢 Type: int64
#       📋 Values: 12
#     📊 Dataset: 02072025/frame_0228/frontal-sinus_mask
#       📏 Shape: (480, 480)
#       🔢 Type: uint8
#     📊 Dataset: 02072025/frame_0228/geniohyoid-muscle_bbox
#       📏 Shape: (4,)
#       🔢 Type: int64
#       📋 Values: [143 323  89  34]
#     📊 Dataset: 02072025/frame_0228/geniohyoid-muscle_contour
#       📏 Shape: (50, 2)
#       🔢 Type: int64
#       📋 Sample: [148 327]
#     📊 Dataset: 02072025/frame_0228/geniohyoid-muscle_id
#       📏 Shape: ()
#       🔢 Type: int64
#       📋 Values: 13
#     📊 Dataset: 02072025/frame_0228/geniohyoid-muscle_mask
#       📏 Shape: (480, 480)
#       🔢 Type: uint8
#     📊 Dataset: 02072025/frame_0228/head_bbox
#       📏 Shape: (4,)
#       🔢 Type: int64
#       📋 Values: [ 34   6 445 473]
#     📊 Dataset: 02072025/frame_0228/head_contour
#       📏 Shape: (243, 2)
#       🔢 Type: int64
#     📊 Dataset: 02072025/frame_0228/head_id
#       📏 Shape: ()
#       🔢 Type: int64
#       📋 Values: 14
#     📊 Dataset: 02072025/frame_0228/head_mask
#       📏 Shape: (480, 480)
#       🔢 Type: uint8
#     📊 Dataset: 02072025/frame_0228/hyoid_bbox
#       📏 Shape: (4,)
#       🔢 Type: int64
#       📋 Values: [232 327  15  15]
#     📊 Dataset: 02072025/frame_0228/hyoid_contour
#       📏 Shape: (25, 2)
#       🔢 Type: int64
#       📋 Sample: [244 327]
#     📊 Dataset: 02072025/frame_0228/hyoid_id
#       📏 Shape: ()
#       🔢 Type: int64
#       📋 Values: 15
#     📊 Dataset: 02072025/frame_0228/hyoid_mask
#       📏 Shape: (480, 480)
#       🔢 Type: uint8
#     📊 Dataset: 02072025/frame_0228/image
#       📏 Shape: (480, 480)
#       🔢 Type: uint8
#     📊 Dataset: 02072025/frame_0228/image_rgb
#       📏 Shape: (480, 480, 3)
#       🔢 Type: uint8
#     📊 Dataset: 02072025/frame_0228/incisior-hard-palate_bbox
#       📏 Shape: (4,)
#       🔢 Type: int64
#       📋 Values: [ 75 176 115  75]
#     📊 Dataset: 02072025/frame_0228/incisior-hard-palate_contour
#       📏 Shape: (40, 2)
#       🔢 Type: int64
#       📋 Sample: [106 176]
#     📊 Dataset: 02072025/frame_0228/incisior-hard-palate_id
#       📏 Shape: ()
#       🔢 Type: int64
#       📋 Values: 16
#     📊 Dataset: 02072025/frame_0228/incisior-hard-palate_mask
#       📏 Shape: (480, 480)
#       🔢 Type: uint8
#     📊 Dataset: 02072025/frame_0228/lower-lip_bbox
#       📏 Shape: (4,)
#       🔢 Type: int64
#       📋 Values: [ 55 258  57  57]
#     📊 Dataset: 02072025/frame_0228/lower-lip_contour
#       📏 Shape: (30, 2)
#       🔢 Type: int64
#       📋 Sample: [112 315]
#     📊 Dataset: 02072025/frame_0228/lower-lip_id
#       📏 Shape: ()
#       🔢 Type: int64
#       📋 Values: 17
#     📊 Dataset: 02072025/frame_0228/lower-lip_mask
#       📏 Shape: (480, 480)
#       🔢 Type: uint8
#     📊 Dataset: 02072025/frame_0228/mandible-incisior_bbox
#       📏 Shape: (4,)
#       🔢 Type: int64
#       📋 Values: [ 86 264  61  97]
#     📊 Dataset: 02072025/frame_0228/mandible-incisior_contour
#       📏 Shape: (40, 2)
#       🔢 Type: int64
# ...
#     📊 Dataset: 02072025/frame_3524/soft-palate-midline_bbox
#       📏 Shape: (4,)
#       🔢 Type: int64
#       📋 Values: [187 202  73  63]
#     📊 Dataset: 02072025/frame_3524/soft-palate-midline_contour
#       📏 Shape: (15, 2)
#       🔢 Type: int64
#       📋 Sample: [187 202]
#     📊 Dataset: 02072025/frame_3524/soft-palate-midline_id
#       📏 Shape: ()
#       🔢 Type: int64
#       📋 Values: 24
#     📊 Dataset: 02072025/frame_3524/soft-palate-midline_mask
#       📏 Shape: (480, 480)
#       🔢 Type: uint8
#     📊 Dataset: 02072025/frame_3524/soft-palate_bbox
#       📏 Shape: (4,)
#       🔢 Type: int64
#       📋 Values: [188 200  78  65]
#     📊 Dataset: 02072025/frame_3524/soft-palate_contour
#       📏 Shape: (33, 2)
#       🔢 Type: int64
#       📋 Sample: [188 200]
#     📊 Dataset: 02072025/frame_3524/soft-palate_id
#       📏 Shape: ()
#       🔢 Type: int64
#       📋 Values: 23
#     📊 Dataset: 02072025/frame_3524/soft-palate_mask
#       📏 Shape: (480, 480)
#       🔢 Type: uint8
#     📊 Dataset: 02072025/frame_3524/sphenoid_bbox
#       📏 Shape: (4,)
#       🔢 Type: int64
#       📋 Values: [225  80 104 116]
#     📊 Dataset: 02072025/frame_3524/sphenoid_contour
#       📏 Shape: (47, 2)
#       🔢 Type: int64
#       📋 Sample: [239  80]
#     📊 Dataset: 02072025/frame_3524/sphenoid_id
#       📏 Shape: ()
#       🔢 Type: int64
#       📋 Values: 25
#     📊 Dataset: 02072025/frame_3524/sphenoid_mask
#       📏 Shape: (480, 480)
#       🔢 Type: uint8
#     📊 Dataset: 02072025/frame_3524/thyroid-cartilage_bbox
#       📏 Shape: (4,)
#       🔢 Type: int64
#       📋 Values: [225 374  13  27]
#     📊 Dataset: 02072025/frame_3524/thyroid-cartilage_contour
#       📏 Shape: (16, 2)
#       🔢 Type: int64
#       📋 Sample: [228 376]
#     📊 Dataset: 02072025/frame_3524/thyroid-cartilage_id
#       📏 Shape: ()
#       🔢 Type: int64
#       📋 Values: 26
#     📊 Dataset: 02072025/frame_3524/thyroid-cartilage_mask
#       📏 Shape: (480, 480)
#       🔢 Type: uint8
#     📊 Dataset: 02072025/frame_3524/tongue-and-floor_bbox
#       📏 Shape: (4,)
#       🔢 Type: int64
#       📋 Values: [ 78 198 185 162]
#     📊 Dataset: 02072025/frame_3524/tongue-and-floor_contour
#       📏 Shape: (224, 2)
#       🔢 Type: int64
#     📊 Dataset: 02072025/frame_3524/tongue-and-floor_id
#       📏 Shape: ()
#       🔢 Type: int64
#       📋 Values: 28
#     📊 Dataset: 02072025/frame_3524/tongue-and-floor_mask
#       📏 Shape: (480, 480)
#       🔢 Type: uint8
#     📊 Dataset: 02072025/frame_3524/tongue-floor_bbox
#       📏 Shape: (4,)
#       🔢 Type: int64
#       📋 Values: [134 363  85  19]
#     📊 Dataset: 02072025/frame_3524/tongue-floor_contour
#       📏 Shape: (23, 2)
#       🔢 Type: int64
#       📋 Sample: [134 368]
#     📊 Dataset: 02072025/frame_3524/tongue-floor_id
#       📏 Shape: ()
#       🔢 Type: int64
#       📋 Values: 29
#     📊 Dataset: 02072025/frame_3524/tongue-floor_mask
#       📏 Shape: (480, 480)
#       🔢 Type: uint8
#     📊 Dataset: 02072025/frame_3524/tongue-muscle_bbox
#       📏 Shape: (4,)
#       🔢 Type: int64
#       📋 Values: [ 78 198 185 140]
#     📊 Dataset: 02072025/frame_3524/tongue-muscle_contour
#       📏 Shape: (60, 2)
#       🔢 Type: int64
#       📋 Sample: [228 338]
#     📊 Dataset: 02072025/frame_3524/tongue-muscle_id
#       📏 Shape: ()
#       🔢 Type: int64
#       📋 Values: 30
#     📊 Dataset: 02072025/frame_3524/tongue-muscle_mask
#       📏 Shape: (480, 480)
#       🔢 Type: uint8
#     📊 Dataset: 02072025/frame_3524/tongue_bbox
#       📏 Shape: (4,)
#       🔢 Type: int64
#       📋 Values: [ 78 198 185 140]
#     📊 Dataset: 02072025/frame_3524/tongue_contour
#       📏 Shape: (60, 2)
#       🔢 Type: int64
#       📋 Sample: [228 338]
#     📊 Dataset: 02072025/frame_3524/tongue_id
#       📏 Shape: ()
#       🔢 Type: int64
#       📋 Values: 27
#     📊 Dataset: 02072025/frame_3524/tongue_mask
#       📏 Shape: (480, 480)
#       🔢 Type: uint8
#     📊 Dataset: 02072025/frame_3524/upper-lip_bbox
#       📏 Shape: (4,)
#       🔢 Type: int64
#       📋 Values: [ 53 189  41  67]
#     📊 Dataset: 02072025/frame_3524/upper-lip_contour
#       📏 Shape: (30, 2)
#       🔢 Type: int64
#       📋 Sample: [ 69 189]
#     📊 Dataset: 02072025/frame_3524/upper-lip_id
#       📏 Shape: ()
#       🔢 Type: int64
#       📋 Values: 31
#     📊 Dataset: 02072025/frame_3524/upper-lip_mask
#       📏 Shape: (480, 480)
#       🔢 Type: uint8
#     📊 Dataset: 02072025/frame_3524/vocal-folds_bbox
#       📏 Shape: (4,)
#       🔢 Type: int64
#       📋 Values: [236 362  28  26]
#     📊 Dataset: 02072025/frame_3524/vocal-folds_contour
#       📏 Shape: (16, 2)
#       🔢 Type: int64
#       📋 Sample: [256 362]
#     📊 Dataset: 02072025/frame_3524/vocal-folds_id
#       📏 Shape: ()
#       🔢 Type: int64
#       📋 Values: 32
#     📊 Dataset: 02072025/frame_3524/vocal-folds_mask
#       📏 Shape: (480, 480)
#       🔢 Type: uint8
#     📊 Dataset: 02072025/frame_3524/vocal-track_bbox
#       📏 Shape: (4,)
#       🔢 Type: int64
#       📋 Values: [240 158  48 182]
#     📊 Dataset: 02072025/frame_3524/vocal-track_contour
#       📏 Shape: (33, 2)
#       🔢 Type: int64
#       📋 Sample: [257 338]
#     📊 Dataset: 02072025/frame_3524/vocal-track_id
#       📏 Shape: ()
#       🔢 Type: int64
#       📋 Values: 33
#     📊 Dataset: 02072025/frame_3524/vocal-track_mask
#       📏 Shape: (480, 480)
#       🔢 Type: uint8
#   📊 Dataset: 02072025/roi_list
#     📏 Shape: (34,)
#     🔢 Type: object
#     📋 Sample: [b'arytenoid-cartilage' b'background' b'brain-stem' b'c1' b'c2']
#
# ==================================================
# 2. LOADING DATA INTO DATAFRAMES
# ==================================================
# Loading data from: FO_BitMapData_2017-110^01-0196-V1MR_S7.h5
# Working with experiment group: 02072025
# Found 20 frames
# Successfully loaded data:
#   - Metadata: 1 rows
#   - Bbox data: 673 rows
#   - Frame summary: 20 rows
#   - ROI summary: 34 rows
#
# ==================================================
# 3. DISPLAYING DATAFRAMES
# ==================================================
#
# 📊 METADATA DataFrame:
# Shape: (1, 6)
# Columns: ['patient', 'serie', 'roi_list', 'clusters_indices', 'experiment_group', 'file_path']
# Sample data:
#                  patient serie  \
# 0  2017-110^01-0196-V1MR     7
#
#                                             roi_list  \
# 0  [arytenoid-cartilage, background, brain-stem, ...
#
#                                     clusters_indices experiment_group  \
# 0  [1, 217, 228, 240, 246, 634, 806, 1005, 1505, ...         02072025
#
#                                           file_path
# 0  ./data/FO_BitMapData_2017-110^01-0196-V1MR_S7.h5
# ------------------------------------------------------------
#
# 📊 BBOX_DATA DataFrame:
# Shape: (673, 18)
# Columns: ['frame_id', 'frame_number', 'roi_name', 'bbox_x', 'bbox_y', 'bbox_width', 'bbox_height', 'bbox_area', 'has_mask', 'has_contour', 'has_id', 'mask_shape', 'mask_nonzero_pixels', 'mask_total_pixels', 'mask_fill_ratio', 'contour_shape', 'contour_points', 'roi_id']
# Sample data:
#      frame_id  frame_number             roi_name  bbox_x  bbox_y  bbox_width  \
# 0  frame_0001             1  arytenoid-cartilage     275     361          21
# 1  frame_0001             1           background       0       0         479
# 2  frame_0001             1           brain-stem     308      12          94
# 3  frame_0001             1                   c1     296     200          24
# 4  frame_0001             1                   c2     297     207          42
#
#    bbox_height  bbox_area  has_mask  has_contour  has_id  mask_shape  \
# 0           47        987      True         True    True  (480, 480)
# 1          479     229441      True         True    True  (480, 480)
# 2          203      19082      True         True    True  (480, 480)
# 3           41        984      True         True    True  (480, 480)
# 4           94       3948      True         True    True  (480, 480)
#
#    mask_nonzero_pixels  mask_total_pixels  mask_fill_ratio contour_shape  \
# 0                  192             230400         0.000833       (21, 2)
# 1                 6147             230400         0.026680      (264, 2)
# 2                11320             230400         0.049132       (50, 2)
# 3                  464             230400         0.002014       (17, 2)
# 4                 2185             230400         0.009484       (20, 2)
#
#    contour_points  roi_id
# 0              21       0
# 1             264       1
# 2              50       2
# 3              17       3
# 4              20       4
# ------------------------------------------------------------
#
# 📊 FRAME_SUMMARY DataFrame:
# Shape: (20, 7)
# Columns: ['frame_id', 'frame_number', 'has_rgb_image', 'has_grayscale_image', 'rgb_image_shape', 'grayscale_image_shape', 'roi_count']
# Sample data:
#      frame_id  frame_number  has_rgb_image  has_grayscale_image  \
# 0  frame_0001             1           True                 True
# 1  frame_0217           217           True                 True
# 2  frame_0228           228           True                 True
# 3  frame_0240           240           True                 True
# 4  frame_0246           246           True                 True
#
#   rgb_image_shape grayscale_image_shape  roi_count
# 0   (480, 480, 3)            (480, 480)         34
# 1   (480, 480, 3)            (480, 480)         34
# 2   (480, 480, 3)            (480, 480)         34
# 3   (480, 480, 3)            (480, 480)         34
# 4   (480, 480, 3)            (480, 480)         33
# ------------------------------------------------------------
#
# 📊 ROI_SUMMARY DataFrame:
# Shape: (34, 18)
# Columns: ['roi_name', 'frame_number_count', 'frame_number_min', 'frame_number_max', 'bbox_area_mean', 'bbox_area_std', 'bbox_area_min', 'bbox_area_max', 'bbox_width_mean', 'bbox_width_std', 'bbox_height_mean', 'bbox_height_std', 'mask_nonzero_pixels_mean', 'mask_nonzero_pixels_std', 'mask_fill_ratio_mean', 'mask_fill_ratio_std', 'contour_points_mean', 'contour_points_std']
# Sample data:
#               roi_name  frame_number_count  frame_number_min  \
# 0  arytenoid-cartilage                  20                 1
# 1           background                  20                 1
# 2           brain-stem                  20                 1
# 3                   c1                  20                 1
# 4                   c2                  20                 1
#
#    frame_number_max  bbox_area_mean  bbox_area_std  bbox_area_min  \
# 0              3524          982.85         379.79            459
# 1              3524       229512.85         234.40         229441
# 2              3524        18507.15         224.39          18216
# 3              3524          884.55         244.81            561
# 4              3524         3946.30           9.65           3906
#
#    bbox_area_max  bbox_width_mean  bbox_width_std  bbox_height_mean  \
# 0           2146            24.50            5.72             39.65
# 1         230399           479.00            0.00            479.15
# 2          19082            91.35            0.75            202.60
# 3           1150            21.90            3.14             39.70
# 4           3956            42.05            0.22             93.85
#
#    bbox_height_std  mask_nonzero_pixels_mean  mask_nonzero_pixels_std  \
# 0             9.96                     207.0                    50.37
# 1             0.49                    6076.7                   454.80
# 2             2.23                   11270.3                   130.95
# 3             5.82                     425.2                   116.74
# 4             0.49                    2174.2                    20.91
#
#    mask_fill_ratio_mean  mask_fill_ratio_std  contour_points_mean  \
# 0                  0.00                  0.0                17.90
# 1                  0.03                  0.0               270.20
# 2                  0.05                  0.0                50.00
# 3                  0.00                  0.0                17.45
# 4                  0.01                  0.0                20.00
#
#    contour_points_std
# 0                5.00
# 1               27.71
# 2                0.00
# 3                2.70
# 4                0.00
# ------------------------------------------------------------
#
# ==================================================
# 4. EXAMPLE: DETAILED ROI DATA
# ==================================================
# Getting detailed data for ROI 'arytenoid-cartilage' in frame 1
# ROI Data keys: ['frame_number', 'roi_name', 'bbox', 'bbox_x', 'bbox_y', 'bbox_width', 'bbox_height', 'mask', 'contour', 'roi_id']
#   frame_number: 1
#   roi_name: arytenoid-cartilage
#   bbox: [275 361  21  47]
#   bbox_x: 275
#   bbox_y: 361
#   bbox_width: 21
#   bbox_height: 47
#   mask: shape (480, 480)
#   contour: shape (21, 2)
#   roi_id: 0
#
# ==================================================
# 5. SAVING DATAFRAMES TO CSV
# ==================================================
# ✅ Saved metadata to ./h5_analysis_output\metadata.csv
# ✅ Saved bbox_data to ./h5_analysis_output\bbox_data.csv
# ✅ Saved frame_summary to ./h5_analysis_output\frame_summary.csv
# ✅ Saved roi_summary to ./h5_analysis_output\roi_summary.csv
#
# 🎉 Analysis complete! Check the './h5_analysis_output' directory for CSV files.

# %%
## Additional Analysis Functions

def analyze_bbox_statistics(bbox_df: pd.DataFrame) -> None:
    """
    Analyze and display statistics about bounding boxes.
    
    Parameters:
    bbox_df (pd.DataFrame): DataFrame containing bbox data
    """
    if bbox_df.empty:
        print("No bbox data available")
        return
    
    print("📊 BOUNDING BOX STATISTICS")
    print("="*40)
    
    # Overall statistics
    print(f"Total bounding boxes: {len(bbox_df)}")
    print(f"Number of unique ROIs: {bbox_df['roi_name'].nunique()}")
    print(f"Number of frames: {bbox_df['frame_number'].nunique()}")
    print(f"Frame range: {bbox_df['frame_number'].min()} - {bbox_df['frame_number'].max()}")
    
    # Area statistics
    print(f"\nArea statistics:")
    print(f"  Mean area: {bbox_df['bbox_area'].mean():.2f}")
    print(f"  Min area: {bbox_df['bbox_area'].min():.2f}")
    print(f"  Max area: {bbox_df['bbox_area'].max():.2f}")
    print(f"  Std area: {bbox_df['bbox_area'].std():.2f}")
    
    # ROI frequency
    print(f"\nROI frequency:")
    roi_counts = bbox_df['roi_name'].value_counts()
    for roi, count in roi_counts.items():
        print(f"  {roi}: {count} frames")


def visualize_bbox_distribution(bbox_df: pd.DataFrame) -> None:
    """
    Create simple visualizations of bbox data distribution.
    
    Parameters:
    bbox_df (pd.DataFrame): DataFrame containing bbox data
    """
    if bbox_df.empty:
        print("No bbox data available for visualization")
        return
    
    try:
        import matplotlib.pyplot as plt
        
        fig, axes = plt.subplots(2, 2, figsize=(12, 8))
        fig.suptitle('Bounding Box Data Analysis', fontsize=16)
        
        # 1. Area distribution
        axes[0, 0].hist(bbox_df['bbox_area'], bins=20, alpha=0.7, edgecolor='black')
        axes[0, 0].set_title('Area Distribution')
        axes[0, 0].set_xlabel('Area (pixels²)')
        axes[0, 0].set_ylabel('Frequency')
        
        # 2. Width vs Height scatter
        axes[0, 1].scatter(bbox_df['bbox_width'], bbox_df['bbox_height'], alpha=0.6)
        axes[0, 1].set_title('Width vs Height')
        axes[0, 1].set_xlabel('Width (pixels)')
        axes[0, 1].set_ylabel('Height (pixels)')
        
        # 3. ROI count per frame
        roi_per_frame = bbox_df.groupby('frame_number').size()
        axes[1, 0].plot(roi_per_frame.index, roi_per_frame.values, marker='o', linewidth=1, markersize=3)
        axes[1, 0].set_title('ROI Count per Frame')
        axes[1, 0].set_xlabel('Frame Number')
        axes[1, 0].set_ylabel('Number of ROIs')
        
        # 4. ROI frequency
        roi_counts = bbox_df['roi_name'].value_counts()
        axes[1, 1].bar(range(len(roi_counts)), roi_counts.values)
        axes[1, 1].set_title('ROI Frequency')
        axes[1, 1].set_xlabel('ROI Index')
        axes[1, 1].set_ylabel('Count')
        axes[1, 1].set_xticks(range(len(roi_counts)))
        axes[1, 1].set_xticklabels(roi_counts.index, rotation=45, ha='right')
        
        plt.tight_layout()
        plt.show()
        
    except ImportError:
        print("Matplotlib not available for visualization")
        print("Install matplotlib to enable visualizations: pip install matplotlib")


def export_roi_masks_summary(h5_filepath: str, roi_name: str) -> pd.DataFrame:
    """
    Export a summary of mask data for a specific ROI across all frames.
    
    Parameters:
    h5_filepath (str): Path to the h5 file
    roi_name (str): Name of the ROI to analyze
    
    Returns:
    pd.DataFrame: Summary of mask data for the ROI
    """
    mask_summary = []
    
    try:
        with h5py.File(h5_filepath, 'r') as h5f:
            exp_group_name = list(h5f.keys())[0]
            exp_group = h5f[exp_group_name]
            
            frame_keys = [key for key in exp_group.keys() if key.startswith('frame_')]
            frame_keys.sort()
            
            for frame_key in frame_keys:
                frame_group = exp_group[frame_key]
                frame_number = int(frame_key.replace('frame_', ''))
                
                mask_key = f'{roi_name}_mask'
                if mask_key in frame_group:
                    mask = frame_group[mask_key][()]
                    
                    summary = {
                        'frame_number': frame_number,
                        'roi_name': roi_name,
                        'mask_height': mask.shape[0],
                        'mask_width': mask.shape[1],
                        'total_pixels': mask.size,
                        'nonzero_pixels': np.count_nonzero(mask),
                        'fill_ratio': np.count_nonzero(mask) / mask.size,
                        'max_value': mask.max(),
                        'mean_value': mask.mean()
                    }
                    
                    mask_summary.append(summary)
    
    except Exception as e:
        print(f"Error analyzing mask data: {e}")
    
    return pd.DataFrame(mask_summary)


# Example usage after running the main analysis
print("🔧 Additional analysis functions defined:")
print("  - analyze_bbox_statistics(bbox_df)")
print("  - visualize_bbox_distribution(bbox_df)")
print("  - export_roi_masks_summary(h5_filepath, roi_name)")
print("\nExample usage:")
print("  analyze_bbox_statistics(dataframes['bbox_data'])")
print("  visualize_bbox_distribution(dataframes['bbox_data'])")
print("  mask_summary = export_roi_masks_summary(h5_filepath, 'head')")
# Out:
# 🔧 Additional analysis functions defined:
#   - analyze_bbox_statistics(bbox_df)
#   - visualize_bbox_distribution(bbox_df)
#   - export_roi_masks_summary(h5_filepath, roi_name)
#
# Example usage:
#   analyze_bbox_statistics(dataframes['bbox_data'])
#   visualize_bbox_distribution(dataframes['bbox_data'])
#   mask_summary = export_roi_masks_summary(h5_filepath, 'head')

# %%
bbox_df = dataframes['bbox_data']
